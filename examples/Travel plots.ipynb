# %%
from pam import read

# %%
pop = read.read_matsim('../tests/test_data/test_matsim_plans.xml')

# %% [markdown]
# You can generate `geopandas.GeoDataFrames` for `Population`'s, `Household`'s or `Person`'s travel. the `route_id`, `service_id` and `network_route` refer to the network used for running the simulation. `GeoDataFrame`s are very useful, they let you to generate geojsons simply and quickly, which you can then load up in kepler.
#
# ```
# gdf.to_file('path/to/file/gdf.geojson'), driver='GeoJSON')
# ```
# note that to use this geojson with kepler you will need the geometry to be in `'epsg:4326'`. You can do this with the method below.

# %%
pop.build_travel_geodataframe(from_epsg='epsg:27700', to_epsg='epsg:4326').head()
# Out:
#                     d_stop          end_location            end_time  \
# 0                     None  (529652.0, 183897.0) 1900-01-01 07:24:52
# 1                     None  (515226.0, 188222.0) 1900-01-01 14:50:52
# 2                     None  (550873.0, 187629.0) 1900-01-01 08:38:15
# 3                     None  (551390.0, 188476.0) 1900-01-01 20:55:49
# 4  9100UPMNSP6.link:302438  (556131.0, 186870.0) 1900-01-01 21:19:59
#
#                                             geometry          mode  \
# 0  LINESTRING (-0.33843 51.58109, -0.13193 51.53909)            pt
# 1  LINESTRING (-0.13193 51.53909, -0.33843 51.58109)            pt
# 2    LINESTRING (0.12334 51.53717, 0.17543 51.56736)  transit_walk
# 3    LINESTRING (0.17543 51.56736, 0.18325 51.57483)  transit_walk
# 4    LINESTRING (0.18325 51.57483, 0.25090 51.55911)            pt
#
#                                        network_route                  o_stop  \
# 0                                               None                    None
# 1                                               None                    None
# 2                                               None                    None
# 3                                               None                    None
# 4  PT1===9100ROMFORD.link:25821===25239===VJ307b9...  9100ROMFORD.link:25821
#
#    purp                                    route_id  seq service_id  \
# 0  None                                        None  1.0       None
# 1  None                                        None  2.0       None
# 2  None                                        None  1.0       None
# 3  None                                        None  2.0       None
# 4  None  VJ307b99b535bf55bc9d62b5475e5edf0d37176bcf  3.0      25239
#
#          start_location          start_time       pid       hid
# 0  (515226.0, 188222.0) 1900-01-01 07:24:52  census_0  census_0
# 1  (529652.0, 183897.0) 1900-01-01 14:50:52  census_0  census_0
# 2  (547360.0, 184166.0) 1900-01-01 06:30:00  census_1  census_1
# 3  (550873.0, 187629.0) 1900-01-01 20:30:00  census_1  census_1
# 4  (551390.0, 188476.0) 1900-01-01 20:55:49  census_1  census_1

# %% [markdown]
# You can also plot travel using plotly. You will need a mapbox token, which you can get here: https://docs.mapbox.com/help/how-mapbox-works/access-tokens/. Be careful not to commit your token in the repo.

# %%
mapbox_access_token='token'

# %% [markdown]
# You need to specify the coordinate system to plot it on a map. By default the plot will colour by mode:

# %% [raw]
# pop.plot_travel_plotly(epsg='epsg:27700',
#                        mapbox_access_token=mapbox_access_token)

# %% [markdown]
# ![default_plot.png](attachment:default_plot.png)

# %% [markdown]
# You can also colour by any column you see in the `GeoDataFrame` (see above). E.g. to colour by agent id (`pid`)

# %% [raw]
# pop.plot_travel_plotly(epsg='epsg:27700',
#                        mapbox_access_token=mapbox_access_token,
#                        colour_by='pid')

# %% [markdown]
# ![colour_by_pid_plot.png](attachment:colour_by_pid_plot.png)

# %% [markdown]
# You can also separate the traces using `groupby` variable:

# %% [raw]
# pop.plot_travel_plotly(epsg='epsg:27700',
#                        mapbox_access_token=mapbox_access_token,
#                        groupby=['hid'])

# %% [markdown]
# ![groupby_hid_plot.png](attachment:groupby_hid_plot.png)
