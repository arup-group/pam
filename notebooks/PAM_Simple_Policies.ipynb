# %%
import os
import pandas as pd
import random
from copy import deepcopy
from collections import defaultdict
import geopandas as gp
from matplotlib import pyplot as plt
from pam import parse

path_to_repo = '/Users/.../PythonProjects/pam'

# %% [markdown]
# ## Load Data
# Here we load simple travel diary data of London commuters. This is a very simple 0.1% sample of data about work and education commutes from the 2011 census. Because we're sharing this date - we've aggregated locations to borough level and randomized personal attributes - so don't get too excited about the results.
#
# The data is available in `pam/example_data`.

# %%
trips = pd.read_csv(os.path.join(path_to_repo, 'example_data', 'example_travel_diaries.csv'))
attributes = pd.read_csv(os.path.join(path_to_repo, 'example_data' , 'example_attributes.csv'))
attributes.set_index('pid', inplace=True)

# %%
attributes.head()
# Out:
#           gender   job    occ     inc
# pid
# census_0  female  work  white     low
# census_1  female  work  white     low
# census_2    male  work   blue    high
# census_3    male  work   blue     low
# census_4    male  work   blue  medium

# %%
trips.head()
# Out:
#    uid       pid       hid  seq      hzone          ozone          dzone  \
# 0    0  census_0  census_0    0     Harrow         Harrow         Camden
# 1    1  census_0  census_0    1     Harrow         Camden         Harrow
# 2    2  census_1  census_1    0  Greenwich      Greenwich  Tower Hamlets
# 3    3  census_1  census_1    1  Greenwich  Tower Hamlets      Greenwich
# 4    4  census_2  census_2    0    Croydon        Croydon        Croydon
#
#    purp mode   tst   tet  freq
# 0  work   pt   444   473  1000
# 1  work   pt   890   919  1000
# 2  work   pt   507   528  1000
# 3  work   pt  1065  1086  1000
# 4  work   pt   422   425  1000

# %%
trips['purp'].unique(), trips['mode'].unique()
# Out:
# (array(['work', 'education'], dtype=object),
#  array(['pt', 'car'], dtype=object))

# %% [markdown]
# ## Imagine we had better data...
#
# Conjure up additional data to aid demonstration.
#
# We add:
# - `age` to person attributes
# - activities:
#     - `leisure`
#     - `health`
#     - `shopping`
# and we put people in shared households based on shared hzone (originally it's one person per household)
#
# **Randomly.**

# %%
import numpy as np

# add age column to attributes
attributes['age'] = [int(a) for a in np.random.normal(40.5, 10, len(attributes))]

# %%
# add some extra activities to trips
zones = list(set(trips['hzone'].unique()) | set(trips['ozone'].unique()) | set(trips['dzone'].unique()))
purp = ['leisure', 'health', 'shopping']
mode = ['pt', 'car', 'walk', 'bike']

def enrich_activities(group):
    new_group = pd.DataFrame(columns=group.columns)
    for idx in group.index:
        trip = group.loc[idx, :]
        try:
            next_start = group.loc[idx+1, :]['tst']
        except KeyError:
            next_start = 1439
        new_group = new_group.append(trip)
        # append a random activity
        activity_loc = random.choice(zones)
        activity_purp = random.choice(purp)
        activity_mode = random.choice(mode)

        act_times = [random.randint(trip['tet']+1, next_start-1) for i in range(4)]
        act_times.sort()

        new_group = new_group.append(pd.DataFrame(
            {'uid': ['{}_act_to'.format(trip['uid']), '{}_act_from'.format(trip['uid'])], 
             'pid': [trip['pid'], trip['pid']], 'hid': [trip['hid'], trip['hid']], 
             'seq': [0, 0], 'hzone': [trip['hzone'], trip['hzone']], 'ozone': [trip['dzone'], activity_loc], 
             'dzone': [activity_loc, trip['ozone']], 'purp': [activity_purp, activity_purp], 
             'mode': [activity_mode, activity_mode], 'tst': [act_times[0], act_times[2]], 
             'tet': [act_times[1], act_times[3]], 'freq': [trip['freq'], trip['freq']]}))
    new_group = new_group.reset_index(drop=True)
    new_group = new_group.drop(['seq'], axis=1)
    new_group = new_group.rename_axis('seq').reset_index()
    return new_group

new_trips = trips.groupby('pid').apply(enrich_activities).reset_index(drop=True)

# %%
# generate some households (as opposed one person to a household)
# bunch up people who share the same hzone
import uuid

def bunch_up_people(group):
    group['pid'].unique()
    households = []
    i = 1
    household= []
    h_size = random.randint(1,5)
    for p in group['pid'].unique():
        household.append(p)
        i += 1

        if i>h_size:
            households.append(household)
            h_size = random.randint(1,5)
            household= []
            i = 1

    return dict(zip([str(uuid.uuid4()) for i in range(len(households))], households))

# %%
households_map = {}
households_per_zone = new_trips.groupby('hzone').apply(bunch_up_people)
for idx in households_per_zone.index:
    households_map = {**households_map, **households_per_zone[idx]}

# %%
# ze old switcheroo person to household id
new_keys = []
new_values = []
for key, value in households_map.items():
    for item in value:
        new_keys.append(item)
        new_values.append(key.lower())
person_to_household_map = dict(zip(new_keys, new_values))

# %%
person_to_household_map
# Out:
# {'census_1016': '9b0da028-8a56-43d8-a5a0-f3a0a3c21afb',
#  'census_1043': '9b0da028-8a56-43d8-a5a0-f3a0a3c21afb',
#  'census_1197': '9b0da028-8a56-43d8-a5a0-f3a0a3c21afb',
#  'census_1247': '9b0da028-8a56-43d8-a5a0-f3a0a3c21afb',
#  'census_1272': '942f912f-3ddf-467e-8ae3-b8a2d8158065',
#  'census_128': '04fa58b2-1995-4836-aba4-ada496f55f3c',
#  'census_1281': '04fa58b2-1995-4836-aba4-ada496f55f3c',
#  'census_1287': '04fa58b2-1995-4836-aba4-ada496f55f3c',
#  'census_1375': '04fa58b2-1995-4836-aba4-ada496f55f3c',
#  'census_1418': '04fa58b2-1995-4836-aba4-ada496f55f3c',
#  'census_1420': 'cd9759ab-5ceb-4415-a98b-11a428913aee',
#  'census_1536': 'cd9759ab-5ceb-4415-a98b-11a428913aee',
#  'census_1665': 'cd9759ab-5ceb-4415-a98b-11a428913aee',
#  'census_1670': 'cd9759ab-5ceb-4415-a98b-11a428913aee',
#  'census_1690': 'b3751ee6-d29c-4328-9364-9a2ceed7b75a',
#  'census_1702': 'b3751ee6-d29c-4328-9364-9a2ceed7b75a',
#  'census_1707': 'b3751ee6-d29c-4328-9364-9a2ceed7b75a',
#  'census_1774': 'dc59e3cf-36f2-42ae-aeac-ac0281e07382',
#  'census_19': 'ebb6b378-0b63-496a-bfef-b4268c22971e',
#  'census_1940': 'ebb6b378-0b63-496a-bfef-b4268c22971e',
#  'census_1986': 'ebb6b378-0b63-496a-bfef-b4268c22971e',
#  'census_2028': 'ebb6b378-0b63-496a-bfef-b4268c22971e',
#  'census_2105': 'adc935c7-2b57-4eb0-85b6-ab6c60c4b069',
#  'census_231': 'adc935c7-2b57-4eb0-85b6-ab6c60c4b069',
#  'census_2352': 'adc935c7-2b57-4eb0-85b6-ab6c60c4b069',
#  'census_2383': 'adc935c7-2b57-4eb0-85b6-ab6c60c4b069',
#  'census_245': '9a720752-415c-4797-8d03-72373c929e0a',
#  'census_2465': '7ed0c5fa-e803-49f1-96fa-5b37aad1f83e',
#  'census_2502': 'c0cbd40f-8631-4184-a2af-de394b1c4b54',
#  'census_2519': 'c0cbd40f-8631-4184-a2af-de394b1c4b54',
#  'census_2587': 'af7dfb36-8190-4430-838f-3caa45bdaf88',
#  'census_2664': 'af7dfb36-8190-4430-838f-3caa45bdaf88',
#  'census_2667': 'af7dfb36-8190-4430-838f-3caa45bdaf88',
#  'census_286': 'af7dfb36-8190-4430-838f-3caa45bdaf88',
#  'census_2860': 'b9946d24-87b1-472d-994c-4e56bd0dd064',
#  'census_298': 'b9946d24-87b1-472d-994c-4e56bd0dd064',
#  'census_302': 'b9946d24-87b1-472d-994c-4e56bd0dd064',
#  'census_37': 'b9946d24-87b1-472d-994c-4e56bd0dd064',
#  'census_399': 'b9946d24-87b1-472d-994c-4e56bd0dd064',
#  'census_52': '719bf8f8-7d7a-4974-ad8a-087c665e5f9a',
#  'census_536': '719bf8f8-7d7a-4974-ad8a-087c665e5f9a',
#  'census_552': 'dd0514f7-1a23-431e-b528-03d50b0f1fd4',
#  'census_579': 'dd0514f7-1a23-431e-b528-03d50b0f1fd4',
#  'census_584': 'dd0514f7-1a23-431e-b528-03d50b0f1fd4',
#  'census_637': '190deca7-0aa0-4af7-ad63-2bc577a87939',
#  'census_732': '190deca7-0aa0-4af7-ad63-2bc577a87939',
#  'census_742': '190deca7-0aa0-4af7-ad63-2bc577a87939',
#  'census_743': '190deca7-0aa0-4af7-ad63-2bc577a87939',
#  'census_793': '190deca7-0aa0-4af7-ad63-2bc577a87939',
#  'census_1008': '948f75be-8b49-4eec-9661-c837ea3ca8fd',
#  'census_1031': '948f75be-8b49-4eec-9661-c837ea3ca8fd',
#  'census_1055': '948f75be-8b49-4eec-9661-c837ea3ca8fd',
#  'census_1059': '948f75be-8b49-4eec-9661-c837ea3ca8fd',
#  'census_1124': '89d2f215-7286-4108-bbae-eeb4c37fabcf',
#  'census_1132': '950b7d56-fb65-490d-a43a-eed8444d7e7b',
#  'census_1143': '950b7d56-fb65-490d-a43a-eed8444d7e7b',
#  'census_1156': '950b7d56-fb65-490d-a43a-eed8444d7e7b',
#  'census_1167': 'a935a19f-559c-4725-b3cf-9ecd8142b315',
#  'census_1187': 'a935a19f-559c-4725-b3cf-9ecd8142b315',
#  'census_1189': 'a935a19f-559c-4725-b3cf-9ecd8142b315',
#  'census_1201': 'dc6c7ac3-b9d9-4b11-a0ef-f88590f603a5',
#  'census_1245': 'dc6c7ac3-b9d9-4b11-a0ef-f88590f603a5',
#  'census_129': 'dc6c7ac3-b9d9-4b11-a0ef-f88590f603a5',
#  'census_131': 'dc6c7ac3-b9d9-4b11-a0ef-f88590f603a5',
#  'census_1349': 'dc6c7ac3-b9d9-4b11-a0ef-f88590f603a5',
#  'census_1358': '1ccaa91a-ffa0-43bc-b27d-f1f1c27c49e6',
#  'census_1362': '1ccaa91a-ffa0-43bc-b27d-f1f1c27c49e6',
#  'census_1408': '62d0e111-6693-44f9-b1a3-a40b41b2bcfa',
#  'census_1436': '62d0e111-6693-44f9-b1a3-a40b41b2bcfa',
#  'census_1454': '62d0e111-6693-44f9-b1a3-a40b41b2bcfa',
#  'census_1460': '62d0e111-6693-44f9-b1a3-a40b41b2bcfa',
#  'census_1485': '62d0e111-6693-44f9-b1a3-a40b41b2bcfa',
#  'census_1489': 'e25ef9d6-88d1-4dce-933b-032be2565898',
#  'census_1504': 'fcc8f89c-1017-49e5-af22-540e96b7c69e',
#  'census_1527': 'e8ea28a9-2b56-4cc8-bba2-2a092cfcce99',
#  'census_1535': '9d7c9e05-0bc0-49ee-9377-ff7e59eb9637',
#  'census_1547': '9d7c9e05-0bc0-49ee-9377-ff7e59eb9637',
#  'census_1550': '9d7c9e05-0bc0-49ee-9377-ff7e59eb9637',
#  'census_1551': '9d7c9e05-0bc0-49ee-9377-ff7e59eb9637',
#  'census_1560': '06e63bcd-e084-4515-bdb3-180253f6792c',
#  'census_1563': '06e63bcd-e084-4515-bdb3-180253f6792c',
#  'census_1584': '21d2f705-1cbc-40b5-9141-85a154b46c5b',
#  'census_1612': '21d2f705-1cbc-40b5-9141-85a154b46c5b',
#  'census_1651': '21d2f705-1cbc-40b5-9141-85a154b46c5b',
#  'census_1653': '21d2f705-1cbc-40b5-9141-85a154b46c5b',
#  'census_1666': '21d2f705-1cbc-40b5-9141-85a154b46c5b',
#  'census_1672': 'cfe5c533-eaeb-466f-9fa0-5b6d071078f5',
#  'census_1692': 'cfe5c533-eaeb-466f-9fa0-5b6d071078f5',
#  'census_1694': 'cb4f0124-1c33-41dd-9035-43f61a93a2b7',
#  'census_1695': 'cb4f0124-1c33-41dd-9035-43f61a93a2b7',
#  'census_1737': '1d59649c-5ac5-4b5d-8c8e-388c26ddce7b',
#  'census_1743': '1d59649c-5ac5-4b5d-8c8e-388c26ddce7b',
#  'census_1758': '1d59649c-5ac5-4b5d-8c8e-388c26ddce7b',
#  'census_1773': '1d59649c-5ac5-4b5d-8c8e-388c26ddce7b',
#  'census_1851': '1d59649c-5ac5-4b5d-8c8e-388c26ddce7b',
#  'census_1885': 'd75f2796-920d-487a-8580-6f7e25a06d43',
#  'census_1888': 'd75f2796-920d-487a-8580-6f7e25a06d43',
#  'census_1892': 'd75f2796-920d-487a-8580-6f7e25a06d43',
#  'census_1900': 'd75f2796-920d-487a-8580-6f7e25a06d43',
#  'census_1902': 'd75f2796-920d-487a-8580-6f7e25a06d43',
#  'census_1903': '9117fb61-1bc4-4be2-8b7a-d3e6d9c08d4e',
#  'census_1912': '849c6bc8-ad81-4a2b-98a2-f5bf6a1a2589',
#  'census_1950': '849c6bc8-ad81-4a2b-98a2-f5bf6a1a2589',
#  'census_1984': 'f0542721-b6ef-4c3e-bae9-53a158ffcfd0',
#  'census_2034': 'ee4d7d5e-dccd-4bcb-aab9-70baec8ba940',
#  'census_2048': 'ee4d7d5e-dccd-4bcb-aab9-70baec8ba940',
#  'census_2099': 'ee4d7d5e-dccd-4bcb-aab9-70baec8ba940',
#  'census_2102': 'cefb2b45-29ee-4eda-936c-24e0be348bd2',
#  'census_2104': 'cefb2b45-29ee-4eda-936c-24e0be348bd2',
#  'census_2130': '6d76bb2b-93a2-4668-bc94-b3fc6b1c6ddd',
#  'census_2147': '6d76bb2b-93a2-4668-bc94-b3fc6b1c6ddd',
#  'census_2194': '7064672b-efee-40de-b1cf-c66209763223',
#  'census_2195': '8f41a4c0-e58c-4290-93a4-c0f02b21759f',
#  'census_2203': '8f41a4c0-e58c-4290-93a4-c0f02b21759f',
#  'census_2251': '8f41a4c0-e58c-4290-93a4-c0f02b21759f',
#  'census_2264': '8f41a4c0-e58c-4290-93a4-c0f02b21759f',
#  'census_2277': '8f41a4c0-e58c-4290-93a4-c0f02b21759f',
#  'census_2288': '4fbb56c3-f723-4cd8-8819-47bdf0f813c6',
#  'census_2294': '4fbb56c3-f723-4cd8-8819-47bdf0f813c6',
#  'census_2310': '4fbb56c3-f723-4cd8-8819-47bdf0f813c6',
#  'census_2316': '4fbb56c3-f723-4cd8-8819-47bdf0f813c6',
#  'census_2338': '079a847c-43e3-4310-9d15-9ff97188c745',
#  'census_234': '079a847c-43e3-4310-9d15-9ff97188c745',
#  'census_2344': '079a847c-43e3-4310-9d15-9ff97188c745',
#  'census_2345': '077118e7-e4ad-4c46-b68a-aab6bb31af5f',
#  'census_2348': '077118e7-e4ad-4c46-b68a-aab6bb31af5f',
#  'census_2388': 'f082d1d8-a9f6-4be1-882e-048fec5f1f6a',
#  'census_2435': 'f082d1d8-a9f6-4be1-882e-048fec5f1f6a',
#  'census_2451': 'f082d1d8-a9f6-4be1-882e-048fec5f1f6a',
#  'census_2455': 'f082d1d8-a9f6-4be1-882e-048fec5f1f6a',
#  'census_2482': 'a749eda9-ed26-42f6-a38a-61a9a8a93113',
#  'census_2510': '23ef6830-8e5e-4786-aed0-ca9764ab25b1',
#  'census_2629': '23ef6830-8e5e-4786-aed0-ca9764ab25b1',
#  'census_2648': '23ef6830-8e5e-4786-aed0-ca9764ab25b1',
#  'census_2698': 'a7ba0696-08df-4b16-9ce5-456ba25c79b0',
#  'census_2703': 'a7ba0696-08df-4b16-9ce5-456ba25c79b0',
#  'census_2710': 'a7ba0696-08df-4b16-9ce5-456ba25c79b0',
#  'census_2736': 'a7ba0696-08df-4b16-9ce5-456ba25c79b0',
#  'census_2744': '5f8fdb3e-8fa9-454c-a452-bbb30b7172e7',
#  'census_2752': 'b9775a26-71d6-48a0-a2c2-5c00f8139650',
#  'census_2782': 'b9775a26-71d6-48a0-a2c2-5c00f8139650',
#  'census_2814': 'b9775a26-71d6-48a0-a2c2-5c00f8139650',
#  'census_2815': 'b9775a26-71d6-48a0-a2c2-5c00f8139650',
#  'census_282': 'b9775a26-71d6-48a0-a2c2-5c00f8139650',
#  'census_2866': 'ba4bc4b4-1bdf-487f-baee-053ed9cc14d3',
#  'census_2897': 'ba4bc4b4-1bdf-487f-baee-053ed9cc14d3',
#  'census_2907': 'ba4bc4b4-1bdf-487f-baee-053ed9cc14d3',
#  'census_295': 'ba4bc4b4-1bdf-487f-baee-053ed9cc14d3',
#  'census_300': 'ba4bc4b4-1bdf-487f-baee-053ed9cc14d3',
#  'census_332': 'bf64660b-8953-4238-a321-3b0c3baeed25',
#  'census_339': 'bf64660b-8953-4238-a321-3b0c3baeed25',
#  'census_401': 'bf64660b-8953-4238-a321-3b0c3baeed25',
#  'census_404': 'bf64660b-8953-4238-a321-3b0c3baeed25',
#  'census_421': 'bf64660b-8953-4238-a321-3b0c3baeed25',
#  'census_436': '50e238b7-dd89-417a-9615-42d144447b0c',
#  'census_45': '2416e8f8-00e1-402b-b591-091a1f799a92',
#  'census_461': '2416e8f8-00e1-402b-b591-091a1f799a92',
#  'census_476': '2416e8f8-00e1-402b-b591-091a1f799a92',
#  'census_491': '95504160-1037-4227-9f9f-af32125e22c7',
#  'census_50': '95504160-1037-4227-9f9f-af32125e22c7',
#  'census_525': 'd6467fd7-04e3-4813-94e8-0e1744f0c33a',
#  'census_530': '097a87c4-9ff6-4330-92fc-8bfcc68d4862',
#  'census_532': '09badbb1-bb1d-418b-9d4d-cfd75cb46f78',
#  'census_533': '09badbb1-bb1d-418b-9d4d-cfd75cb46f78',
#  'census_57': '09badbb1-bb1d-418b-9d4d-cfd75cb46f78',
#  'census_583': '09badbb1-bb1d-418b-9d4d-cfd75cb46f78',
#  'census_587': 'f18d9e24-a77e-43d3-ac3d-0fa6ec49df05',
#  'census_589': 'f18d9e24-a77e-43d3-ac3d-0fa6ec49df05',
#  'census_601': 'f18d9e24-a77e-43d3-ac3d-0fa6ec49df05',
#  'census_615': 'f18d9e24-a77e-43d3-ac3d-0fa6ec49df05',
#  'census_627': 'f18d9e24-a77e-43d3-ac3d-0fa6ec49df05',
#  'census_649': '796e376a-6aca-4da0-80ed-ded3cca678cb',
#  'census_665': '796e376a-6aca-4da0-80ed-ded3cca678cb',
#  'census_692': '796e376a-6aca-4da0-80ed-ded3cca678cb',
#  'census_705': '796e376a-6aca-4da0-80ed-ded3cca678cb',
#  'census_760': '796e376a-6aca-4da0-80ed-ded3cca678cb',
#  'census_762': '2c7f0c35-f5f0-4742-b824-29fc922fab27',
#  'census_768': '2c7f0c35-f5f0-4742-b824-29fc922fab27',
#  'census_776': '2c7f0c35-f5f0-4742-b824-29fc922fab27',
#  'census_795': '570036f5-5bd6-4902-b7f8-0b0f9051a46e',
#  'census_815': '570036f5-5bd6-4902-b7f8-0b0f9051a46e',
#  'census_82': '570036f5-5bd6-4902-b7f8-0b0f9051a46e',
#  'census_820': '570036f5-5bd6-4902-b7f8-0b0f9051a46e',
#  'census_839': '570036f5-5bd6-4902-b7f8-0b0f9051a46e',
#  'census_87': '4dbfdc3f-0092-4330-821d-d2b5de9e3b1e',
#  'census_882': '4dbfdc3f-0092-4330-821d-d2b5de9e3b1e',
#  'census_92': '4dbfdc3f-0092-4330-821d-d2b5de9e3b1e',
#  'census_956': '4dbfdc3f-0092-4330-821d-d2b5de9e3b1e',
#  'census_1011': '1f75b508-a43e-4b73-9013-0c579c1e296f',
#  'census_1045': '1f75b508-a43e-4b73-9013-0c579c1e296f',
#  'census_1057': '1f75b508-a43e-4b73-9013-0c579c1e296f',
#  'census_1073': '1f75b508-a43e-4b73-9013-0c579c1e296f',
#  'census_1144': '60316ec9-489a-472c-9fc5-cd41f24b98c4',
#  'census_1162': '60316ec9-489a-472c-9fc5-cd41f24b98c4',
#  'census_1171': '60316ec9-489a-472c-9fc5-cd41f24b98c4',
#  'census_1199': '60316ec9-489a-472c-9fc5-cd41f24b98c4',
#  'census_120': '60316ec9-489a-472c-9fc5-cd41f24b98c4',
#  'census_1205': '3bbaa49d-c2c1-4f29-93e2-c8bc33ab2a25',
#  'census_1253': '3bbaa49d-c2c1-4f29-93e2-c8bc33ab2a25',
#  'census_1278': '3bbaa49d-c2c1-4f29-93e2-c8bc33ab2a25',
#  'census_1280': '3bbaa49d-c2c1-4f29-93e2-c8bc33ab2a25',
#  'census_133': '51388773-c4b4-4c7d-bdd5-7e1e942b260c',
#  'census_1364': '51388773-c4b4-4c7d-bdd5-7e1e942b260c',
#  'census_1414': 'dd044d35-f7d6-4167-a4e5-d518944ed533',
#  'census_144': 'dd044d35-f7d6-4167-a4e5-d518944ed533',
#  'census_145': '6fe84a7d-b37f-4e03-8388-dc2c32d0f980',
#  'census_1474': '6fe84a7d-b37f-4e03-8388-dc2c32d0f980',
#  'census_1499': '6fe84a7d-b37f-4e03-8388-dc2c32d0f980',
#  'census_1544': '6fe84a7d-b37f-4e03-8388-dc2c32d0f980',
#  'census_1568': 'aed83d09-31b6-4ab0-a0da-e01a4056add7',
#  'census_1576': 'aed83d09-31b6-4ab0-a0da-e01a4056add7',
#  'census_1600': 'aed83d09-31b6-4ab0-a0da-e01a4056add7',
#  'census_1603': 'aed83d09-31b6-4ab0-a0da-e01a4056add7',
#  'census_1667': 'f0fe4fdf-2c2a-44fc-b084-20ab90f0902f',
#  'census_1734': 'f0fe4fdf-2c2a-44fc-b084-20ab90f0902f',
#  'census_1833': '5fa380d3-d72a-4b42-b03c-0973aff63977',
#  'census_191': '5fa380d3-d72a-4b42-b03c-0973aff63977',
#  'census_1913': 'a6d90851-89b0-420d-80ba-b88eae6724d6',
#  'census_1999': 'adbbf4b0-c8d6-44c6-9569-28d43fbb6c39',
#  'census_2018': 'adbbf4b0-c8d6-44c6-9569-28d43fbb6c39',
#  'census_2020': 'adbbf4b0-c8d6-44c6-9569-28d43fbb6c39',
#  'census_2021': 'adbbf4b0-c8d6-44c6-9569-28d43fbb6c39',
#  'census_2042': 'adbbf4b0-c8d6-44c6-9569-28d43fbb6c39',
#  'census_208': '86ddcd98-87e0-45bf-a903-38374a60c48c',
#  'census_2082': '86ddcd98-87e0-45bf-a903-38374a60c48c',
#  'census_2110': '86ddcd98-87e0-45bf-a903-38374a60c48c',
#  'census_2155': '86ddcd98-87e0-45bf-a903-38374a60c48c',
#  'census_2314': '987ed2ac-723e-4567-86a6-99d58fccbf3a',
#  'census_2332': '987ed2ac-723e-4567-86a6-99d58fccbf3a',
#  'census_2358': '987ed2ac-723e-4567-86a6-99d58fccbf3a',
#  'census_2369': 'fbf92eb9-3650-41cd-b35b-80d2f68e661c',
#  'census_2374': 'fbf92eb9-3650-41cd-b35b-80d2f68e661c',
#  'census_2377': 'fbf92eb9-3650-41cd-b35b-80d2f68e661c',
#  'census_2488': 'fbf92eb9-3650-41cd-b35b-80d2f68e661c',
#  'census_2492': 'fbf92eb9-3650-41cd-b35b-80d2f68e661c',
#  'census_2495': 'd004c581-dbbb-41cf-b102-09f2937fc4d9',
#  'census_2561': 'd004c581-dbbb-41cf-b102-09f2937fc4d9',
#  'census_2571': 'ff6fbf0f-c319-4505-aabf-e2a18428e651',
#  'census_2610': 'ff6fbf0f-c319-4505-aabf-e2a18428e651',
#  'census_262': 'ff6fbf0f-c319-4505-aabf-e2a18428e651',
#  'census_2640': 'ff6fbf0f-c319-4505-aabf-e2a18428e651',
#  'census_2663': 'ff6fbf0f-c319-4505-aabf-e2a18428e651',
#  'census_2666': '4ca35e1b-c100-4b95-afc0-f3903cc5eec2',
#  'census_2827': '4ca35e1b-c100-4b95-afc0-f3903cc5eec2',
#  'census_2873': '4ca35e1b-c100-4b95-afc0-f3903cc5eec2',
#  'census_2874': '4ca35e1b-c100-4b95-afc0-f3903cc5eec2',
#  'census_308': 'f70d8f5a-163c-4883-b596-d178066d3414',
#  'census_359': 'f70d8f5a-163c-4883-b596-d178066d3414',
#  'census_363': 'f70d8f5a-163c-4883-b596-d178066d3414',
#  'census_369': 'f70d8f5a-163c-4883-b596-d178066d3414',
#  'census_392': 'ee17e6bb-6a6b-4d48-ae97-095a591562c4',
#  'census_484': 'ee17e6bb-6a6b-4d48-ae97-095a591562c4',
#  'census_590': 'ee17e6bb-6a6b-4d48-ae97-095a591562c4',
#  'census_625': 'cf374a60-e227-44d0-8956-d830e6392992',
#  'census_663': 'cf374a60-e227-44d0-8956-d830e6392992',
#  'census_675': '953b0484-ad8e-4b4e-a61e-1ea8a369641d',
#  'census_701': '953b0484-ad8e-4b4e-a61e-1ea8a369641d',
#  'census_738': '6b16b11d-3ebf-402b-9dad-3f5b3a665ded',
#  'census_74': '6b16b11d-3ebf-402b-9dad-3f5b3a665ded',
#  'census_769': '6b16b11d-3ebf-402b-9dad-3f5b3a665ded',
#  'census_851': '9347de10-cc16-4f5d-a1bd-25629f845630',
#  'census_921': '9347de10-cc16-4f5d-a1bd-25629f845630',
#  'census_928': '9347de10-cc16-4f5d-a1bd-25629f845630',
#  'census_1020': '8c2901c9-8436-4204-90c0-183fcd6ef596',
#  'census_1076': '8c2901c9-8436-4204-90c0-183fcd6ef596',
#  'census_110': '8c2901c9-8436-4204-90c0-183fcd6ef596',
#  'census_1109': '25d77c3d-e8a3-492d-8aca-d5d9c7ed1084',
#  'census_1131': '25d77c3d-e8a3-492d-8aca-d5d9c7ed1084',
#  'census_1168': '25d77c3d-e8a3-492d-8aca-d5d9c7ed1084',
#  'census_1186': 'd70e2ce6-7fa7-4bcb-96e1-8830a038f7f4',
#  'census_1217': 'd70e2ce6-7fa7-4bcb-96e1-8830a038f7f4',
#  'census_1234': '9c6efbd5-0cdb-4135-a372-df23ce2903ce',
#  'census_125': '9c6efbd5-0cdb-4135-a372-df23ce2903ce',
#  'census_1259': '9c6efbd5-0cdb-4135-a372-df23ce2903ce',
#  'census_1318': '788f42c5-44f2-4029-b36e-7c400fa10a4e',
#  'census_1326': '788f42c5-44f2-4029-b36e-7c400fa10a4e',
#  'census_1342': '6304fe65-90ae-49dd-91d8-593650ea0b0f',
#  'census_1367': '6304fe65-90ae-49dd-91d8-593650ea0b0f',
#  'census_139': '6304fe65-90ae-49dd-91d8-593650ea0b0f',
#  'census_1403': '6304fe65-90ae-49dd-91d8-593650ea0b0f',
#  'census_1406': '6304fe65-90ae-49dd-91d8-593650ea0b0f',
#  'census_1441': 'e218210b-84c7-4bff-8eb3-cd89ebe57412',
#  'census_1453': 'e218210b-84c7-4bff-8eb3-cd89ebe57412',
#  'census_1502': '60666886-8848-4235-885c-c493634f16ed',
#  'census_1531': '60666886-8848-4235-885c-c493634f16ed',
#  'census_1593': 'cdb488cd-cecb-4a2f-bd08-176c9d4a9a72',
#  'census_1598': 'cdb488cd-cecb-4a2f-bd08-176c9d4a9a72',
#  'census_1629': 'cdb488cd-cecb-4a2f-bd08-176c9d4a9a72',
#  'census_1636': '6c2d401a-3b97-4981-8d97-0d372049e0bb',
#  'census_1688': '6c2d401a-3b97-4981-8d97-0d372049e0bb',
#  'census_1720': '6c2d401a-3b97-4981-8d97-0d372049e0bb',
#  'census_1726': '6c2d401a-3b97-4981-8d97-0d372049e0bb',
#  'census_173': '6c2d401a-3b97-4981-8d97-0d372049e0bb',
#  'census_1745': 'd4e4afd6-00c0-4e36-8a19-98a1e6ecd173',
#  'census_1763': 'd4e4afd6-00c0-4e36-8a19-98a1e6ecd173',
#  'census_1775': 'd4e4afd6-00c0-4e36-8a19-98a1e6ecd173',
#  'census_1798': 'd4e4afd6-00c0-4e36-8a19-98a1e6ecd173',
#  'census_1801': '61bcc12b-09a8-4868-911c-5b2f4c23b1cc',
#  'census_1808': '61bcc12b-09a8-4868-911c-5b2f4c23b1cc',
#  'census_1860': '61bcc12b-09a8-4868-911c-5b2f4c23b1cc',
#  'census_1869': '8907a7bd-fcc3-4671-809d-780bc56007ce',
#  'census_1878': '8907a7bd-fcc3-4671-809d-780bc56007ce',
#  'census_1948': '8907a7bd-fcc3-4671-809d-780bc56007ce',
#  'census_1959': '8907a7bd-fcc3-4671-809d-780bc56007ce',
#  'census_1970': '8907a7bd-fcc3-4671-809d-780bc56007ce',
#  'census_1993': 'ccd29811-f58d-408b-b9cb-88a2ef6c4a35',
#  'census_2013': 'ccd29811-f58d-408b-b9cb-88a2ef6c4a35',
#  'census_2027': 'ccd29811-f58d-408b-b9cb-88a2ef6c4a35',
#  'census_2055': 'ccd29811-f58d-408b-b9cb-88a2ef6c4a35',
#  'census_2056': 'ccd29811-f58d-408b-b9cb-88a2ef6c4a35',
#  'census_2059': '417c234d-52b9-46cd-972c-7a34c012436a',
#  'census_2061': '417c234d-52b9-46cd-972c-7a34c012436a',
#  'census_2083': '417c234d-52b9-46cd-972c-7a34c012436a',
#  'census_2095': '417c234d-52b9-46cd-972c-7a34c012436a',
#  'census_2101': '417c234d-52b9-46cd-972c-7a34c012436a',
#  'census_2121': '3a168539-fbf0-40bd-8510-68829f59414d',
#  'census_2139': '3a168539-fbf0-40bd-8510-68829f59414d',
#  'census_214': '3a168539-fbf0-40bd-8510-68829f59414d',
#  'census_217': '3a168539-fbf0-40bd-8510-68829f59414d',
#  'census_2236': 'e2bab501-b25a-4b31-9952-7344783a1ee2',
#  'census_2278': 'e2bab501-b25a-4b31-9952-7344783a1ee2',
#  'census_2297': 'b5165cc8-ea3a-468a-8815-219ea21d1ead',
#  'census_2363': 'b5165cc8-ea3a-468a-8815-219ea21d1ead',
#  'census_2364': '6c3002c5-2f18-437d-9a2a-d40bf7cd1738',
#  'census_2445': '6c3002c5-2f18-437d-9a2a-d40bf7cd1738',
#  'census_2458': 'fd955691-3cd3-441c-94f1-e36f742765bd',
#  'census_2461': 'fd955691-3cd3-441c-94f1-e36f742765bd',
#  'census_2480': 'fd955691-3cd3-441c-94f1-e36f742765bd',
#  'census_2516': 'e0d6661e-84a3-4203-8b9d-d7bdf897b48a',
#  'census_2523': 'e0d6661e-84a3-4203-8b9d-d7bdf897b48a',
#  'census_2573': 'e0d6661e-84a3-4203-8b9d-d7bdf897b48a',
#  'census_2578': 'a13cdd7f-7f5a-42be-84d3-5458ea437e36',
#  'census_2588': 'a13cdd7f-7f5a-42be-84d3-5458ea437e36',
#  'census_2609': 'a13cdd7f-7f5a-42be-84d3-5458ea437e36',
#  'census_2658': 'a13cdd7f-7f5a-42be-84d3-5458ea437e36',
#  'census_2661': '0786cd66-7ea7-48a9-8b53-85d1f8554c26',
#  'census_268': '0786cd66-7ea7-48a9-8b53-85d1f8554c26',
#  'census_2681': '0786cd66-7ea7-48a9-8b53-85d1f8554c26',
#  'census_2693': '0786cd66-7ea7-48a9-8b53-85d1f8554c26',
#  'census_2694': '7fa44579-cbea-4a49-ba0b-13136ad5ff10',
#  'census_270': '7fa44579-cbea-4a49-ba0b-13136ad5ff10',
#  'census_2735': '7fa44579-cbea-4a49-ba0b-13136ad5ff10',
#  'census_2740': '7fa44579-cbea-4a49-ba0b-13136ad5ff10',
#  'census_277': '50556bd2-aa4a-4976-ad21-8f4535432c47',
#  'census_2780': '50556bd2-aa4a-4976-ad21-8f4535432c47',
#  'census_2792': '50556bd2-aa4a-4976-ad21-8f4535432c47',
#  'census_2795': '50556bd2-aa4a-4976-ad21-8f4535432c47',
#  'census_2853': '32334e5b-fea8-4964-9827-793c636cd128',
#  'census_297': '32334e5b-fea8-4964-9827-793c636cd128',
#  'census_322': '32334e5b-fea8-4964-9827-793c636cd128',
#  'census_341': '32334e5b-fea8-4964-9827-793c636cd128',
#  'census_38': '36900e63-94f2-4651-9ba6-a0d0ed6d8b2e',
#  'census_393': '36900e63-94f2-4651-9ba6-a0d0ed6d8b2e',
#  'census_407': '36900e63-94f2-4651-9ba6-a0d0ed6d8b2e',
#  'census_420': 'ea4e0c61-da0c-41a6-bf17-218fa10b6362',
#  'census_431': 'ea4e0c61-da0c-41a6-bf17-218fa10b6362',
#  'census_456': 'ea4e0c61-da0c-41a6-bf17-218fa10b6362',
#  'census_471': 'ea4e0c61-da0c-41a6-bf17-218fa10b6362',
#  'census_509': '4558182e-6601-43bf-acc0-606717546ac0',
#  'census_511': '4558182e-6601-43bf-acc0-606717546ac0',
#  'census_513': 'ebea0163-0441-48b0-9a6e-d4b3dcf181dd',
#  'census_523': 'ebea0163-0441-48b0-9a6e-d4b3dcf181dd',
#  'census_750': 'ebea0163-0441-48b0-9a6e-d4b3dcf181dd',
#  'census_765': 'd1269968-0f6b-4f31-a5d4-ca45fbdc9f92',
#  'census_814': 'd1269968-0f6b-4f31-a5d4-ca45fbdc9f92',
#  'census_817': 'd1269968-0f6b-4f31-a5d4-ca45fbdc9f92',
#  'census_827': 'b73bf853-0591-4dc6-8306-f8195cdb7a25',
#  'census_849': 'b73bf853-0591-4dc6-8306-f8195cdb7a25',
#  'census_1013': '9ed1ebc4-318b-48c5-905d-5a1bc6153266',
#  'census_1040': '9ed1ebc4-318b-48c5-905d-5a1bc6153266',
#  'census_1047': '9ed1ebc4-318b-48c5-905d-5a1bc6153266',
#  'census_1048': '9ed1ebc4-318b-48c5-905d-5a1bc6153266',
#  'census_112': '767c1cc0-bbfb-4111-9d17-2b9a6d122c53',
#  'census_115': 'dec2b8da-5e64-4a61-8030-e10d28d34fb5',
#  'census_1208': 'dec2b8da-5e64-4a61-8030-e10d28d34fb5',
#  'census_126': 'dec2b8da-5e64-4a61-8030-e10d28d34fb5',
#  'census_1268': '0fa9bb57-de8d-4d53-9382-341eefa56654',
#  'census_1283': '0fa9bb57-de8d-4d53-9382-341eefa56654',
#  'census_1301': '0fa9bb57-de8d-4d53-9382-341eefa56654',
#  'census_1304': '0fa9bb57-de8d-4d53-9382-341eefa56654',
#  'census_1309': '0fa9bb57-de8d-4d53-9382-341eefa56654',
#  'census_1357': '7010fef3-cba1-429d-bf3f-21b2be56d2de',
#  'census_1381': '7010fef3-cba1-429d-bf3f-21b2be56d2de',
#  'census_1387': '7010fef3-cba1-429d-bf3f-21b2be56d2de',
#  'census_1409': '7010fef3-cba1-429d-bf3f-21b2be56d2de',
#  'census_1458': '7010fef3-cba1-429d-bf3f-21b2be56d2de',
#  'census_1481': 'bebf559a-683e-4332-adb6-923667eb3927',
#  'census_1501': 'bebf559a-683e-4332-adb6-923667eb3927',
#  'census_1534': 'bebf559a-683e-4332-adb6-923667eb3927',
#  'census_1569': 'bebf559a-683e-4332-adb6-923667eb3927',
#  'census_1642': 'bebf559a-683e-4332-adb6-923667eb3927',
#  'census_1645': '50d91895-4da2-4e51-82c1-d9068d9624ac',
#  'census_1718': '50d91895-4da2-4e51-82c1-d9068d9624ac',
#  'census_1725': 'f7d94b5b-9273-42bf-9dd7-ae1aa3847c08',
#  'census_1769': 'f7d94b5b-9273-42bf-9dd7-ae1aa3847c08',
#  'census_1786': 'f7d94b5b-9273-42bf-9dd7-ae1aa3847c08',
#  'census_1818': 'f7d94b5b-9273-42bf-9dd7-ae1aa3847c08',
#  'census_1882': 'f7d94b5b-9273-42bf-9dd7-ae1aa3847c08',
#  'census_1890': 'd3fe90c1-8b00-4b39-9093-86057f179e0c',
#  'census_1931': 'd3fe90c1-8b00-4b39-9093-86057f179e0c',
#  'census_1941': 'd3fe90c1-8b00-4b39-9093-86057f179e0c',
#  'census_1949': '4d624d43-b9d4-4d19-a303-73814595d618',
#  'census_1978': 'be555474-e199-490b-940e-c666a61ec6e1',
#  'census_2090': 'be555474-e199-490b-940e-c666a61ec6e1',
#  'census_2154': 'be555474-e199-490b-940e-c666a61ec6e1',
#  'census_2161': 'be555474-e199-490b-940e-c666a61ec6e1',
#  'census_2162': 'c29f7c9d-9773-4494-980d-8c35c94093d3',
#  'census_2165': 'c29f7c9d-9773-4494-980d-8c35c94093d3',
#  'census_2199': 'c29f7c9d-9773-4494-980d-8c35c94093d3',
#  'census_221': '109ad79e-af61-4e14-a729-0131fd37aaf6',
#  'census_2219': '109ad79e-af61-4e14-a729-0131fd37aaf6',
#  'census_2262': '109ad79e-af61-4e14-a729-0131fd37aaf6',
#  'census_2267': '109ad79e-af61-4e14-a729-0131fd37aaf6',
#  'census_2282': '38447d59-1dbb-4d81-a539-e003c7fdf91d',
#  'census_2342': '38447d59-1dbb-4d81-a539-e003c7fdf91d',
#  'census_2395': '38447d59-1dbb-4d81-a539-e003c7fdf91d',
#  'census_2570': '38447d59-1dbb-4d81-a539-e003c7fdf91d',
#  'census_2606': '38447d59-1dbb-4d81-a539-e003c7fdf91d',
#  'census_2637': 'd6e6069c-4fcd-46fe-b41e-104ce2f8c1b1',
#  'census_2639': 'd6e6069c-4fcd-46fe-b41e-104ce2f8c1b1',
#  'census_2642': '796bcbe3-2c2b-4c68-8cf4-52479e202cd5',
#  'census_2647': '796bcbe3-2c2b-4c68-8cf4-52479e202cd5',
#  'census_2679': '191353c6-84d2-4d49-ae8b-f9d8ad173011',
#  'census_2683': '9346fef7-fe82-41c1-90d6-6280d51a3623',
#  'census_27': '9346fef7-fe82-41c1-90d6-6280d51a3623',
#  'census_2721': 'df62460a-33d4-440f-82f9-b3c0cadb9db7',
#  'census_2761': 'df62460a-33d4-440f-82f9-b3c0cadb9db7',
#  'census_2769': 'df62460a-33d4-440f-82f9-b3c0cadb9db7',
#  'census_2817': 'df62460a-33d4-440f-82f9-b3c0cadb9db7',
#  'census_2830': 'cb5de088-ae7f-4ec9-aa51-ca9bfa8e1292',
#  'census_2847': 'cb5de088-ae7f-4ec9-aa51-ca9bfa8e1292',
#  'census_2855': '9a8f1c4d-a43a-4734-a41b-20bd4a57ce36',
#  'census_2892': '9a8f1c4d-a43a-4734-a41b-20bd4a57ce36',
#  'census_296': '9a8f1c4d-a43a-4734-a41b-20bd4a57ce36',
#  'census_317': '03282df7-3b25-4ac7-8189-f35dc779365d',
#  'census_353': '03282df7-3b25-4ac7-8189-f35dc779365d',
#  'census_355': '03282df7-3b25-4ac7-8189-f35dc779365d',
#  'census_386': 'fe105b7b-b892-4371-a91d-978f7ae9a2f0',
#  'census_387': 'fe105b7b-b892-4371-a91d-978f7ae9a2f0',
#  'census_406': 'fe105b7b-b892-4371-a91d-978f7ae9a2f0',
#  'census_433': 'a013d155-031a-44f2-8513-f0bde2240f7a',
#  'census_449': 'a013d155-031a-44f2-8513-f0bde2240f7a',
#  'census_465': 'ceb934f3-70b2-4794-ae11-c09dd0cf5638',
#  'census_474': 'ceb934f3-70b2-4794-ae11-c09dd0cf5638',
#  'census_493': 'ceb934f3-70b2-4794-ae11-c09dd0cf5638',
#  'census_531': 'ceb934f3-70b2-4794-ae11-c09dd0cf5638',
#  'census_554': '10991f2d-3bbc-4a93-a05a-2d669a0d6bd8',
#  'census_597': '10991f2d-3bbc-4a93-a05a-2d669a0d6bd8',
#  'census_605': '10991f2d-3bbc-4a93-a05a-2d669a0d6bd8',
#  'census_606': '10991f2d-3bbc-4a93-a05a-2d669a0d6bd8',
#  'census_639': '10991f2d-3bbc-4a93-a05a-2d669a0d6bd8',
#  'census_65': '15418bd2-9486-4ba6-96c5-fe8221a72edf',
#  'census_657': '6a908879-e9ea-4214-b873-7609acdb372a',
#  'census_661': 'f924d196-2615-4930-b720-0669969e9c21',
#  'census_67': 'f924d196-2615-4930-b720-0669969e9c21',
#  'census_695': 'b6d70735-a1ee-4f25-9827-0baa0dfbd079',
#  'census_714': 'b6d70735-a1ee-4f25-9827-0baa0dfbd079',
#  'census_716': 'b6d70735-a1ee-4f25-9827-0baa0dfbd079',
#  'census_72': 'b6d70735-a1ee-4f25-9827-0baa0dfbd079',
#  'census_758': 'b6d70735-a1ee-4f25-9827-0baa0dfbd079',
#  'census_77': 'df47b3e2-1e4c-4037-96d5-e5611a30f593',
#  'census_81': 'df47b3e2-1e4c-4037-96d5-e5611a30f593',
#  'census_845': '5565ca11-e9fc-416d-a8b3-e6e7069e2fd7',
#  'census_847': '5565ca11-e9fc-416d-a8b3-e6e7069e2fd7',
#  'census_853': '5565ca11-e9fc-416d-a8b3-e6e7069e2fd7',
#  'census_856': '5565ca11-e9fc-416d-a8b3-e6e7069e2fd7',
#  'census_920': '0e2580ce-a1b7-402f-9154-5afeb0400a1e',
#  'census_967': '0e2580ce-a1b7-402f-9154-5afeb0400a1e',
#  'census_977': '0e2580ce-a1b7-402f-9154-5afeb0400a1e',
#  'census_103': '9dff2daa-dc10-414d-8be0-52d7701fd5f3',
#  'census_1052': '9dff2daa-dc10-414d-8be0-52d7701fd5f3',
#  'census_1064': '9dff2daa-dc10-414d-8be0-52d7701fd5f3',
#  'census_1070': '9dff2daa-dc10-414d-8be0-52d7701fd5f3',
#  'census_1115': '3219c6ad-a967-461f-9c9b-b8dd65500034',
#  'census_1137': '3219c6ad-a967-461f-9c9b-b8dd65500034',
#  'census_1263': '3219c6ad-a967-461f-9c9b-b8dd65500034',
#  'census_1267': '3219c6ad-a967-461f-9c9b-b8dd65500034',
#  'census_1298': '3219c6ad-a967-461f-9c9b-b8dd65500034',
#  'census_1319': 'd5a28242-1391-4f93-a785-b024499f4dc5',
#  'census_1346': 'd5a28242-1391-4f93-a785-b024499f4dc5',
#  'census_1388': 'd5a28242-1391-4f93-a785-b024499f4dc5',
#  'census_1391': 'd5a28242-1391-4f93-a785-b024499f4dc5',
#  'census_1415': '0abdf66b-80f9-45a6-846a-c8fb30d4f882',
#  'census_1440': 'cd7db86f-b2c9-4980-9e2c-f9bedbcc8b9e',
#  'census_1564': 'cd7db86f-b2c9-4980-9e2c-f9bedbcc8b9e',
#  'census_1605': '32544225-3e6e-4598-9da7-930af38fa097',
#  'census_1628': '32544225-3e6e-4598-9da7-930af38fa097',
#  'census_1664': '32544225-3e6e-4598-9da7-930af38fa097',
#  'census_1704': '32544225-3e6e-4598-9da7-930af38fa097',
#  'census_1705': 'e85b91e1-ea98-4bc6-954f-58b3eef7b591',
#  'census_1736': 'e85b91e1-ea98-4bc6-954f-58b3eef7b591',
#  'census_1762': 'e85b91e1-ea98-4bc6-954f-58b3eef7b591',
#  'census_1781': 'efd56a47-f346-441d-81e8-524b366787fc',
#  'census_1826': 'efd56a47-f346-441d-81e8-524b366787fc',
#  'census_184': 'efd56a47-f346-441d-81e8-524b366787fc',
#  'census_1845': 'd9862d5e-b3aa-4a43-b605-f64b65fc7efc',
#  'census_1895': 'd9862d5e-b3aa-4a43-b605-f64b65fc7efc',
#  'census_1934': 'd9862d5e-b3aa-4a43-b605-f64b65fc7efc',
#  'census_2010': '64d9e7af-84ed-4734-9fb0-bc9094447731',
#  'census_2058': '64d9e7af-84ed-4734-9fb0-bc9094447731',
#  'census_2086': '64d9e7af-84ed-4734-9fb0-bc9094447731',
#  'census_2098': '2c8b935d-eeb1-4f73-a0b7-897fcbb21473',
#  'census_2108': '2c8b935d-eeb1-4f73-a0b7-897fcbb21473',
#  'census_2135': '2c8b935d-eeb1-4f73-a0b7-897fcbb21473',
#  'census_2152': '2c8b935d-eeb1-4f73-a0b7-897fcbb21473',
#  'census_2232': '2c8b935d-eeb1-4f73-a0b7-897fcbb21473',
#  'census_2257': '8f3c60f8-5a69-4402-96f5-166b7aa8445c',
#  'census_2382': '8f3c60f8-5a69-4402-96f5-166b7aa8445c',
#  'census_2385': '8f3c60f8-5a69-4402-96f5-166b7aa8445c',
#  'census_2427': '8f3c60f8-5a69-4402-96f5-166b7aa8445c',
#  'census_2476': 'f85a4c74-2bf7-4051-9ea6-a9109d68ad74',
#  'census_2532': 'f85a4c74-2bf7-4051-9ea6-a9109d68ad74',
#  'census_2536': 'f85a4c74-2bf7-4051-9ea6-a9109d68ad74',
#  'census_2566': 'f85a4c74-2bf7-4051-9ea6-a9109d68ad74',
#  'census_2567': '1a450a7e-d273-4bdd-9f1f-235d9af0fc2d',
#  'census_258': '1a450a7e-d273-4bdd-9f1f-235d9af0fc2d',
#  'census_2619': 'b55e7e23-2317-436c-a366-2d45818d0926',
#  'census_2671': 'b55e7e23-2317-436c-a366-2d45818d0926',
#  'census_2739': 'b55e7e23-2317-436c-a366-2d45818d0926',
#  'census_2775': 'b55e7e23-2317-436c-a366-2d45818d0926',
#  'census_2826': 'b3bb86ea-92ee-4c29-b1a3-6a16fe9ad40e',
#  'census_283': 'b3bb86ea-92ee-4c29-b1a3-6a16fe9ad40e',
#  'census_288': 'b3bb86ea-92ee-4c29-b1a3-6a16fe9ad40e',
#  'census_30': 'b3bb86ea-92ee-4c29-b1a3-6a16fe9ad40e',
#  'census_330': 'b3bb86ea-92ee-4c29-b1a3-6a16fe9ad40e',
#  'census_333': 'a47aa499-87c8-4fe6-9e43-ff2250010300',
#  'census_381': 'a47aa499-87c8-4fe6-9e43-ff2250010300',
#  'census_409': 'a47aa499-87c8-4fe6-9e43-ff2250010300',
#  'census_478': '134ba8d4-969c-40c4-bb9f-de60ed6dde5a',
#  'census_489': '134ba8d4-969c-40c4-bb9f-de60ed6dde5a',
#  'census_49': '134ba8d4-969c-40c4-bb9f-de60ed6dde5a',
#  'census_63': '80b8ee03-d07c-4182-895e-b8d3ea995bda',
#  'census_636': '80b8ee03-d07c-4182-895e-b8d3ea995bda',
#  'census_646': '80b8ee03-d07c-4182-895e-b8d3ea995bda',
#  'census_699': '80b8ee03-d07c-4182-895e-b8d3ea995bda',
#  'census_726': '80b8ee03-d07c-4182-895e-b8d3ea995bda',
#  'census_811': '8b85a66c-cf09-4ee4-bcf7-bf4ff80339bb',
#  'census_840': '8b85a66c-cf09-4ee4-bcf7-bf4ff80339bb',
#  'census_883': '8b85a66c-cf09-4ee4-bcf7-bf4ff80339bb',
#  'census_897': '8b85a66c-cf09-4ee4-bcf7-bf4ff80339bb',
#  'census_10': 'b8cfa00f-8ade-411b-8606-91093419c4ea',
#  'census_1009': 'b8cfa00f-8ade-411b-8606-91093419c4ea',
#  'census_1050': 'b8cfa00f-8ade-411b-8606-91093419c4ea',
#  'census_1054': 'a1d5876b-4920-41c0-97c1-0ac7ee84ce13',
#  'census_1097': 'a1d5876b-4920-41c0-97c1-0ac7ee84ce13',
#  'census_1098': 'a1d5876b-4920-41c0-97c1-0ac7ee84ce13',
#  'census_1128': '9583d151-07be-4405-a6cc-8fc13bd4b02d',
#  'census_1172': '9583d151-07be-4405-a6cc-8fc13bd4b02d',
#  'census_1176': '9583d151-07be-4405-a6cc-8fc13bd4b02d',
#  'census_1179': 'b6e8855f-8a0b-4a00-a0a2-177cb6ca5182',
#  'census_12': 'b6e8855f-8a0b-4a00-a0a2-177cb6ca5182',
#  'census_1210': 'b6e8855f-8a0b-4a00-a0a2-177cb6ca5182',
#  'census_1227': 'b418b7ee-325f-4450-8264-fc58cc533308',
#  'census_1244': 'b418b7ee-325f-4450-8264-fc58cc533308',
#  'census_1246': '17d08621-dbe4-47a4-9281-c9780aeecbdd',
#  'census_1270': '17d08621-dbe4-47a4-9281-c9780aeecbdd',
#  'census_1274': '17d08621-dbe4-47a4-9281-c9780aeecbdd',
#  'census_1343': '27e6c0dc-6a60-475c-b1ab-d759f35e01a6',
#  'census_1389': '27e6c0dc-6a60-475c-b1ab-d759f35e01a6',
#  'census_141': '97b3b59e-6b54-493f-b39e-856503625797',
#  'census_1428': '97b3b59e-6b54-493f-b39e-856503625797',
#  'census_1442': '97b3b59e-6b54-493f-b39e-856503625797',
#  'census_147': '97b3b59e-6b54-493f-b39e-856503625797',
#  'census_1483': '5377862a-d2d7-4ef7-a35d-f00817881741',
#  'census_1486': '71ccb8e5-e750-476a-b127-101c7c6c3f82',
#  'census_151': '71ccb8e5-e750-476a-b127-101c7c6c3f82',
#  'census_1522': '71ccb8e5-e750-476a-b127-101c7c6c3f82',
#  'census_1572': '271232c8-3242-497e-91c7-511c58f349f9',
#  'census_1582': 'fb27ea3d-b24b-4f71-a627-aa61a7ea3fdc',
#  'census_162': 'e797c4d4-e723-4bc5-b869-644ca67acd3d',
#  'census_1630': '3ee40f02-2472-4cbb-8130-c9e80aac2c6c',
#  'census_1641': '3ee40f02-2472-4cbb-8130-c9e80aac2c6c',
#  'census_1675': '3ee40f02-2472-4cbb-8130-c9e80aac2c6c',
#  'census_171': '3ee40f02-2472-4cbb-8130-c9e80aac2c6c',
#  'census_1716': '3ee40f02-2472-4cbb-8130-c9e80aac2c6c',
#  'census_1735': '9ba75783-cf3c-42da-b809-5e5a315c7a24',
#  'census_1741': '9ba75783-cf3c-42da-b809-5e5a315c7a24',
#  'census_178': '9ba75783-cf3c-42da-b809-5e5a315c7a24',
#  'census_1800': '9ba75783-cf3c-42da-b809-5e5a315c7a24',
#  'census_1807': '33920f66-1273-4d35-b00a-bb55ee4897f5',
#  'census_1815': '33920f66-1273-4d35-b00a-bb55ee4897f5',
#  'census_1821': '33920f66-1273-4d35-b00a-bb55ee4897f5',
#  'census_1855': '33920f66-1273-4d35-b00a-bb55ee4897f5',
#  'census_1896': 'd82ead72-fbeb-4871-9ca3-1c5e2e7fd8e3',
#  'census_1897': '144b4207-3c25-41c3-9519-09da7eeecdcf',
#  'census_1898': 'f9d3f5c6-5c99-40db-8de4-d0dd595fff8d',
#  'census_1908': 'f9d3f5c6-5c99-40db-8de4-d0dd595fff8d',
#  'census_1918': '64b8f1ac-6d5b-4a6d-a62d-b8dcef65c288',
#  'census_1921': '64b8f1ac-6d5b-4a6d-a62d-b8dcef65c288',
#  'census_2': '64b8f1ac-6d5b-4a6d-a62d-b8dcef65c288',
#  'census_2006': '3acf7a34-baed-4683-879b-76f64e5309b9',
#  'census_201': '3acf7a34-baed-4683-879b-76f64e5309b9',
#  'census_2040': '3acf7a34-baed-4683-879b-76f64e5309b9',
#  'census_2046': '3acf7a34-baed-4683-879b-76f64e5309b9',
#  'census_206': '5f214b6d-f3a8-4401-b3ba-16e2da18ae51',
#  'census_2062': '5f214b6d-f3a8-4401-b3ba-16e2da18ae51',
#  'census_2075': '5f214b6d-f3a8-4401-b3ba-16e2da18ae51',
#  'census_2077': '5f214b6d-f3a8-4401-b3ba-16e2da18ae51',
#  'census_210': 'e6cbd4ea-41a8-46c4-b6ea-3a540798bf7b',
#  'census_2122': '456646ef-8d7c-447c-ae98-c8fe11a5f06a',
#  'census_2136': '456646ef-8d7c-447c-ae98-c8fe11a5f06a',
#  'census_2142': '456646ef-8d7c-447c-ae98-c8fe11a5f06a',
#  'census_2179': '456646ef-8d7c-447c-ae98-c8fe11a5f06a',
#  'census_2188': '456646ef-8d7c-447c-ae98-c8fe11a5f06a',
#  'census_219': 'f89b3e26-877f-4bcc-856c-708d8f126c75',
#  'census_2222': 'f89b3e26-877f-4bcc-856c-708d8f126c75',
#  'census_2235': 'f89b3e26-877f-4bcc-856c-708d8f126c75',
#  'census_2269': 'f89b3e26-877f-4bcc-856c-708d8f126c75',
#  'census_2286': 'f89b3e26-877f-4bcc-856c-708d8f126c75',
#  'census_2329': 'da06879b-d211-47af-b321-af532d390710',
#  'census_2333': 'da06879b-d211-47af-b321-af532d390710',
#  'census_2357': 'da06879b-d211-47af-b321-af532d390710',
#  'census_238': 'da06879b-d211-47af-b321-af532d390710',
#  'census_2398': 'e612e7e1-217f-4096-b3a9-311a42c45d8c',
#  'census_2407': '98f095f5-de05-4133-b9ca-a5dd1f78a6d7',
#  'census_2423': '98f095f5-de05-4133-b9ca-a5dd1f78a6d7',
#  'census_2430': '98f095f5-de05-4133-b9ca-a5dd1f78a6d7',
#  'census_2433': '70651da6-30ef-4188-8588-556953e1a530',
#  'census_2438': '70651da6-30ef-4188-8588-556953e1a530',
#  'census_2449': '7f3ef983-9746-4cfc-ad07-32dabfe07a57',
#  'census_2452': 'dd46d944-7c46-4c10-acb3-9c1d38f9f282',
#  'census_2463': '6dbe995f-42d3-444d-a705-4bb8a91f25b7',
#  'census_2474': '6dbe995f-42d3-444d-a705-4bb8a91f25b7',
#  'census_2489': '6dbe995f-42d3-444d-a705-4bb8a91f25b7',
#  'census_2552': '6dbe995f-42d3-444d-a705-4bb8a91f25b7',
#  'census_2565': '6dbe995f-42d3-444d-a705-4bb8a91f25b7',
#  'census_2577': '7953bbed-01b5-4b7c-b080-6d95c1cf7877',
#  'census_2599': '7953bbed-01b5-4b7c-b080-6d95c1cf7877',
#  'census_2607': '7953bbed-01b5-4b7c-b080-6d95c1cf7877',
#  'census_2612': '7953bbed-01b5-4b7c-b080-6d95c1cf7877',
#  'census_2644': '7953bbed-01b5-4b7c-b080-6d95c1cf7877',
#  'census_271': '91e0f8ef-bfff-4450-93bf-f4957ef813d4',
#  'census_2719': '91e0f8ef-bfff-4450-93bf-f4957ef813d4',
#  'census_276': '91e0f8ef-bfff-4450-93bf-f4957ef813d4',
#  'census_2764': '91e0f8ef-bfff-4450-93bf-f4957ef813d4',
#  'census_2766': '91e0f8ef-bfff-4450-93bf-f4957ef813d4',
#  'census_279': '98e6081b-fae4-44a5-abb2-806305b22472',
#  'census_28': '98e6081b-fae4-44a5-abb2-806305b22472',
#  'census_2843': '3f22b357-a216-4a0d-8fd9-b81d13f5f2fb',
#  'census_2861': '3f22b357-a216-4a0d-8fd9-b81d13f5f2fb',
#  'census_2876': 'ab4f5369-b860-4562-a2b6-5c4926dbcc90',
#  'census_2878': 'ab4f5369-b860-4562-a2b6-5c4926dbcc90',
#  'census_2888': 'ab4f5369-b860-4562-a2b6-5c4926dbcc90',
#  'census_2923': 'ab4f5369-b860-4562-a2b6-5c4926dbcc90',
#  'census_305': '3c52c658-0478-4d3e-a60d-71820b8a274d',
#  'census_323': '3c52c658-0478-4d3e-a60d-71820b8a274d',
#  'census_324': '3c52c658-0478-4d3e-a60d-71820b8a274d',
#  'census_389': '3c52c658-0478-4d3e-a60d-71820b8a274d',
#  'census_42': 'e6abae85-c941-4185-9d0e-89ae1bd2dcf8',
#  'census_459': 'e6abae85-c941-4185-9d0e-89ae1bd2dcf8',
#  'census_494': 'e6abae85-c941-4185-9d0e-89ae1bd2dcf8',
#  'census_508': 'fad0e2f0-f8e9-4028-97bc-aa3b3b3bd269',
#  'census_516': 'fad0e2f0-f8e9-4028-97bc-aa3b3b3bd269',
#  'census_604': 'fad0e2f0-f8e9-4028-97bc-aa3b3b3bd269',
#  'census_609': 'dcbd7e3c-2bca-4ab4-992b-1082f91ad3f3',
#  'census_617': '9a5a57b4-39fb-4875-8f14-e2c082c8f180',
#  'census_624': '9a5a57b4-39fb-4875-8f14-e2c082c8f180',
#  'census_641': '9a5a57b4-39fb-4875-8f14-e2c082c8f180',
#  'census_683': '9a5a57b4-39fb-4875-8f14-e2c082c8f180',
#  'census_690': '9a5a57b4-39fb-4875-8f14-e2c082c8f180',
#  'census_700': '3864faac-7fad-4ec8-8f32-c87971c565da',
#  'census_718': '3864faac-7fad-4ec8-8f32-c87971c565da',
#  'census_719': '3864faac-7fad-4ec8-8f32-c87971c565da',
#  'census_720': '3864faac-7fad-4ec8-8f32-c87971c565da',
#  'census_737': '3864faac-7fad-4ec8-8f32-c87971c565da',
#  'census_744': 'eaf00594-8de0-4683-aaba-7a96903710b3',
#  'census_773': 'eaf00594-8de0-4683-aaba-7a96903710b3',
#  'census_78': 'eaf00594-8de0-4683-aaba-7a96903710b3',
#  'census_788': '8faa024c-83a8-4a9d-8557-d3cd83d19417',
#  'census_805': '8faa024c-83a8-4a9d-8557-d3cd83d19417',
#  'census_874': '8faa024c-83a8-4a9d-8557-d3cd83d19417',
#  'census_889': '8faa024c-83a8-4a9d-8557-d3cd83d19417',
#  'census_890': '054d3c4a-a4e1-4be1-8c15-fb58b0f0dd8e',
#  'census_9': 'b96acb6f-8047-47ce-b081-58dc815646d3',
#  'census_903': 'b96acb6f-8047-47ce-b081-58dc815646d3',
#  'census_910': 'b96acb6f-8047-47ce-b081-58dc815646d3',
#  'census_924': 'b96acb6f-8047-47ce-b081-58dc815646d3',
#  'census_938': 'b96acb6f-8047-47ce-b081-58dc815646d3',
#  'census_1058': 'dbdaa525-840a-4286-9247-0ba8698013d9',
#  'census_108': 'dbdaa525-840a-4286-9247-0ba8698013d9',
#  'census_1092': 'dbdaa525-840a-4286-9247-0ba8698013d9',
#  'census_1122': 'dbdaa525-840a-4286-9247-0ba8698013d9',
#  'census_1142': '3eab5af8-dc79-43d9-8eda-100d59ced3e6',
#  'census_1178': '3eab5af8-dc79-43d9-8eda-100d59ced3e6',
#  'census_1182': '3eab5af8-dc79-43d9-8eda-100d59ced3e6',
#  'census_1226': 'b9a6e540-efa3-425a-ace0-08cc1eea323c',
#  'census_1241': 'b9a6e540-efa3-425a-ace0-08cc1eea323c',
#  'census_1320': 'b9a6e540-efa3-425a-ace0-08cc1eea323c',
#  'census_1334': '62c6725f-01d3-49be-ba7e-dcb202167bfe',
#  'census_1344': '62c6725f-01d3-49be-ba7e-dcb202167bfe',
#  'census_1390': '62c6725f-01d3-49be-ba7e-dcb202167bfe',
#  'census_1434': '62c6725f-01d3-49be-ba7e-dcb202167bfe',
#  'census_1448': '62c6725f-01d3-49be-ba7e-dcb202167bfe',
#  'census_1456': '0fcb1798-0b89-4002-8a43-14e5647db120',
#  'census_16': '0fcb1798-0b89-4002-8a43-14e5647db120',
#  'census_1622': '0fcb1798-0b89-4002-8a43-14e5647db120',
#  'census_1663': '0fcb1798-0b89-4002-8a43-14e5647db120',
#  'census_1668': 'b44b7aa3-f358-4213-80a6-de1f7c3d2f27',
#  'census_1693': 'b44b7aa3-f358-4213-80a6-de1f7c3d2f27',
#  'census_1712': 'b44b7aa3-f358-4213-80a6-de1f7c3d2f27',
#  'census_1767': 'ddc0806e-5ea1-4f01-9eaf-8c80dea1099d',
#  'census_1780': 'ddc0806e-5ea1-4f01-9eaf-8c80dea1099d',
#  'census_1848': 'ddc0806e-5ea1-4f01-9eaf-8c80dea1099d',
#  'census_1925': 'ddc0806e-5ea1-4f01-9eaf-8c80dea1099d',
#  'census_1933': 'db864681-fb50-402a-bbad-588e03202898',
#  'census_1935': '2333b109-3e8c-4a8a-9826-cc36011d3796',
#  'census_1958': '2333b109-3e8c-4a8a-9826-cc36011d3796',
#  'census_1988': '2333b109-3e8c-4a8a-9826-cc36011d3796',
#  'census_2005': '2333b109-3e8c-4a8a-9826-cc36011d3796',
#  'census_2051': '767d39b7-e89f-42fb-9153-ccb512d3e4a1',
#  'census_2163': '767d39b7-e89f-42fb-9153-ccb512d3e4a1',
#  'census_2177': 'd35cc0dc-214d-409c-b14e-55933e341004',
#  'census_2200': 'e057f036-70e4-49fb-93ab-6a1a0653a02b',
#  'census_2210': 'e057f036-70e4-49fb-93ab-6a1a0653a02b',
#  'census_2218': 'e057f036-70e4-49fb-93ab-6a1a0653a02b',
#  'census_2244': 'e057f036-70e4-49fb-93ab-6a1a0653a02b',
#  'census_2272': 'e057f036-70e4-49fb-93ab-6a1a0653a02b',
#  'census_2298': '21871cf9-d1dd-47de-ad90-abe0ce29b329',
#  'census_2306': '21871cf9-d1dd-47de-ad90-abe0ce29b329',
#  'census_2317': '21871cf9-d1dd-47de-ad90-abe0ce29b329',
#  'census_2326': '21871cf9-d1dd-47de-ad90-abe0ce29b329',
#  'census_2336': '6c3cf676-5dd9-4826-9051-b21ca6fabcde',
#  'census_235': '6c3cf676-5dd9-4826-9051-b21ca6fabcde',
#  'census_2415': '70c5d8b3-0a50-4fec-90d1-959d938894f8',
#  'census_2429': '70c5d8b3-0a50-4fec-90d1-959d938894f8',
#  'census_2434': '70c5d8b3-0a50-4fec-90d1-959d938894f8',
#  'census_2441': '6a05204a-c055-4f6a-9b4a-e2f97cc83a5b',
#  'census_2503': '9770c9e8-821c-4010-a8a0-391553ac8354',
#  'census_2524': '98da72c9-2b2e-40de-819f-c3349d91d760',
#  'census_2556': '98da72c9-2b2e-40de-819f-c3349d91d760',
#  'census_2582': '98da72c9-2b2e-40de-819f-c3349d91d760',
#  'census_2594': '98da72c9-2b2e-40de-819f-c3349d91d760',
#  'census_2618': '57b1e7c5-01ad-4aeb-b806-a28bffb8823a',
#  'census_2626': '57b1e7c5-01ad-4aeb-b806-a28bffb8823a',
#  'census_2641': '57b1e7c5-01ad-4aeb-b806-a28bffb8823a',
#  'census_2645': '57b1e7c5-01ad-4aeb-b806-a28bffb8823a',
#  'census_2677': 'f8d91b6b-5063-488d-910b-8921167e3583',
#  'census_2717': 'f8d91b6b-5063-488d-910b-8921167e3583',
#  'census_2729': 'f8d91b6b-5063-488d-910b-8921167e3583',
#  'census_2742': 'f8d91b6b-5063-488d-910b-8921167e3583',
#  'census_2763': 'f8d91b6b-5063-488d-910b-8921167e3583',
#  'census_2774': '017c5568-73d6-40ed-b8fa-012ab4961573',
#  'census_2776': '4f2a87f7-62c8-4a8d-b08f-65eefee0aeb3',
#  'census_280': '4f2a87f7-62c8-4a8d-b08f-65eefee0aeb3',
#  'census_2829': '4f2a87f7-62c8-4a8d-b08f-65eefee0aeb3',
#  'census_289': '4f2a87f7-62c8-4a8d-b08f-65eefee0aeb3',
#  'census_307': '4f2a87f7-62c8-4a8d-b08f-65eefee0aeb3',
#  'census_313': 'f41ef583-bc55-42cc-90fb-b7ddcad89b59',
#  'census_320': 'f41ef583-bc55-42cc-90fb-b7ddcad89b59',
#  'census_335': 'f41ef583-bc55-42cc-90fb-b7ddcad89b59',
#  'census_373': 'f41ef583-bc55-42cc-90fb-b7ddcad89b59',
#  'census_40': 'f41ef583-bc55-42cc-90fb-b7ddcad89b59',
#  'census_423': 'b03e5204-339d-4e76-9d5e-a0b1b0cec701',
#  'census_432': 'b03e5204-339d-4e76-9d5e-a0b1b0cec701',
#  'census_462': 'b03e5204-339d-4e76-9d5e-a0b1b0cec701',
#  'census_463': 'b03e5204-339d-4e76-9d5e-a0b1b0cec701',
#  'census_470': 'aa6dfde5-1c25-440b-969a-e9e856dcf6be',
#  'census_504': 'aa6dfde5-1c25-440b-969a-e9e856dcf6be',
#  'census_51': 'c1db7689-3737-4c50-b5d3-a1625481c1fd',
#  'census_519': 'c1db7689-3737-4c50-b5d3-a1625481c1fd',
#  'census_53': 'c1db7689-3737-4c50-b5d3-a1625481c1fd',
#  'census_586': 'c1db7689-3737-4c50-b5d3-a1625481c1fd',
#  'census_588': '8f44a4ec-3ea2-4039-a660-092ba10329ac',
#  'census_595': '8f44a4ec-3ea2-4039-a660-092ba10329ac',
#  'census_610': '8f44a4ec-3ea2-4039-a660-092ba10329ac',
#  'census_62': 'b006e597-604d-4c71-ae89-d733a81c5922',
#  'census_629': 'b006e597-604d-4c71-ae89-d733a81c5922',
#  'census_635': 'b006e597-604d-4c71-ae89-d733a81c5922',
#  'census_7': 'b006e597-604d-4c71-ae89-d733a81c5922',
#  'census_741': 'e4d77b48-40e8-45b8-94e4-4eaac7de5a23',
#  'census_786': 'e4d77b48-40e8-45b8-94e4-4eaac7de5a23',
#  'census_830': 'e4d77b48-40e8-45b8-94e4-4eaac7de5a23',
#  'census_831': 'e4d77b48-40e8-45b8-94e4-4eaac7de5a23',
#  'census_86': 'e4d77b48-40e8-45b8-94e4-4eaac7de5a23',
#  'census_879': 'c7ae482a-c6c1-4e2e-993b-fc69379d34c0',
#  'census_880': 'c7ae482a-c6c1-4e2e-993b-fc69379d34c0',
#  'census_900': 'c7ae482a-c6c1-4e2e-993b-fc69379d34c0',
#  'census_955': 'c7ae482a-c6c1-4e2e-993b-fc69379d34c0',
#  'census_98': '11de00f6-ef4e-488f-84d0-6c1c8fac89f2',
#  'census_980': '11de00f6-ef4e-488f-84d0-6c1c8fac89f2',
#  'census_989': '11de00f6-ef4e-488f-84d0-6c1c8fac89f2',
#  'census_995': '54713fed-51d0-4dbf-94ac-0a95cd982fdb',
#  'census_1026': 'b288353d-e5a4-4cf6-83e0-306c0bbbfb4a',
#  'census_1037': 'b288353d-e5a4-4cf6-83e0-306c0bbbfb4a',
#  'census_1094': 'f57a6197-1ba6-48bc-a8bf-6aea65f9e7e8',
#  'census_1135': 'f57a6197-1ba6-48bc-a8bf-6aea65f9e7e8',
#  'census_1136': '77a9af0d-ed43-48ea-badd-32b5272fe0b4',
#  'census_1163': '77a9af0d-ed43-48ea-badd-32b5272fe0b4',
#  'census_1165': '77a9af0d-ed43-48ea-badd-32b5272fe0b4',
#  'census_1173': '77a9af0d-ed43-48ea-badd-32b5272fe0b4',
#  'census_1207': 'e7f7305b-fd01-4731-b43a-513898a10af2',
#  'census_1251': 'e7f7305b-fd01-4731-b43a-513898a10af2',
#  'census_1255': 'e7f7305b-fd01-4731-b43a-513898a10af2',
#  'census_1293': '3f80284b-e0d1-4a93-a5f9-bc443718cff5',
#  'census_1312': '4b1a45d5-a822-4c23-ac49-c77057fdac4b',
#  'census_136': '6d21dd66-0713-44e3-9ed7-711facd23c86',
#  'census_1365': '6d21dd66-0713-44e3-9ed7-711facd23c86',
#  'census_1374': '6d21dd66-0713-44e3-9ed7-711facd23c86',
#  'census_1396': '6d21dd66-0713-44e3-9ed7-711facd23c86',
#  'census_1421': '6d21dd66-0713-44e3-9ed7-711facd23c86',
#  'census_1424': '75c8bedb-9592-4d27-877c-a7e49cd7be70',
#  'census_1445': '4d2ca3f6-e1b0-4e4a-a47c-51ac10b11d22',
#  'census_1484': '4d2ca3f6-e1b0-4e4a-a47c-51ac10b11d22',
#  'census_1503': '335d3895-7835-40ad-9787-80b4cfea9698',
#  'census_1512': '335d3895-7835-40ad-9787-80b4cfea9698',
#  'census_1513': '0166ee41-04d6-45a3-8ae1-e208a2d6ba17',
#  'census_1524': '0166ee41-04d6-45a3-8ae1-e208a2d6ba17',
#  'census_153': '0166ee41-04d6-45a3-8ae1-e208a2d6ba17',
#  'census_1606': '0166ee41-04d6-45a3-8ae1-e208a2d6ba17',
#  'census_1611': '50b5fcb5-b62a-41cc-99c6-cd1ff9683029',
#  'census_1673': '50b5fcb5-b62a-41cc-99c6-cd1ff9683029',
#  'census_1750': '50b5fcb5-b62a-41cc-99c6-cd1ff9683029',
#  'census_1771': '50b5fcb5-b62a-41cc-99c6-cd1ff9683029',
#  'census_1939': '50b5fcb5-b62a-41cc-99c6-cd1ff9683029',
#  'census_1954': '8bcaae2c-2395-4010-9d35-a354f8701b8d',
#  'census_197': '8bcaae2c-2395-4010-9d35-a354f8701b8d',
#  'census_1982': '8bcaae2c-2395-4010-9d35-a354f8701b8d',
#  'census_1995': '8bcaae2c-2395-4010-9d35-a354f8701b8d',
#  'census_2015': 'a31b4d70-0e5c-405f-8f30-a6a971877271',
#  'census_2024': 'a31b4d70-0e5c-405f-8f30-a6a971877271',
#  'census_2043': 'a31b4d70-0e5c-405f-8f30-a6a971877271',
#  'census_2052': 'ac7a681b-9e78-434b-809d-3b75ac159f3b',
#  'census_2065': 'ac7a681b-9e78-434b-809d-3b75ac159f3b',
#  'census_2068': 'ac7a681b-9e78-434b-809d-3b75ac159f3b',
#  'census_2092': 'ac7a681b-9e78-434b-809d-3b75ac159f3b',
#  'census_2156': 'ac7a681b-9e78-434b-809d-3b75ac159f3b',
#  'census_2164': '45b11516-ef50-4e5f-8956-905bec0e064e',
#  'census_2176': 'ac4c6ac4-decc-494b-97df-f95df2ec5a40',
#  'census_2190': 'ac4c6ac4-decc-494b-97df-f95df2ec5a40',
#  'census_2208': 'ac4c6ac4-decc-494b-97df-f95df2ec5a40',
#  'census_2209': 'ac4c6ac4-decc-494b-97df-f95df2ec5a40',
#  'census_2224': 'ac4c6ac4-decc-494b-97df-f95df2ec5a40',
#  'census_2225': '313401c9-d80f-4f66-ab4c-a3bcfeaac4fa',
#  'census_223': '313401c9-d80f-4f66-ab4c-a3bcfeaac4fa',
#  'census_2299': '313401c9-d80f-4f66-ab4c-a3bcfeaac4fa',
#  'census_2327': '313401c9-d80f-4f66-ab4c-a3bcfeaac4fa',
#  'census_2408': '972d597d-add1-4cad-a6b6-e5c16ecaddfa',
#  'census_2437': '972d597d-add1-4cad-a6b6-e5c16ecaddfa',
#  'census_2443': '972d597d-add1-4cad-a6b6-e5c16ecaddfa',
#  'census_2467': 'fd2f34dc-56ba-4443-9fbc-4b80242164bc',
#  'census_2518': 'fd2f34dc-56ba-4443-9fbc-4b80242164bc',
#  'census_2540': 'fd2f34dc-56ba-4443-9fbc-4b80242164bc',
#  'census_2550': 'fd2f34dc-56ba-4443-9fbc-4b80242164bc',
#  'census_2554': 'fd2f34dc-56ba-4443-9fbc-4b80242164bc',
#  'census_2603': 'd1837874-ddd1-42e3-bf1c-091c8ca8d0fe',
#  'census_2630': 'd1837874-ddd1-42e3-bf1c-091c8ca8d0fe',
#  'census_2659': 'ba55125e-3ad8-4e28-bec9-6a2a9885cb78',
#  'census_2757': '61955998-53e7-43e7-ae0a-990d13daf7ba',
#  'census_2770': '61955998-53e7-43e7-ae0a-990d13daf7ba',
#  'census_2777': '22175036-d203-486e-9d04-bf50ffb8cfa3',
#  'census_2778': '22175036-d203-486e-9d04-bf50ffb8cfa3',
#  'census_2794': '22175036-d203-486e-9d04-bf50ffb8cfa3',
#  'census_2798': 'df8b41f4-6e1a-437d-b1a5-e7fc9d3d9c06',
#  'census_2839': 'df8b41f4-6e1a-437d-b1a5-e7fc9d3d9c06',
#  'census_2841': 'df8b41f4-6e1a-437d-b1a5-e7fc9d3d9c06',
#  'census_2868': 'df8b41f4-6e1a-437d-b1a5-e7fc9d3d9c06',
#  'census_2885': '4a33b32c-1a71-47b6-afed-4920726840f0',
#  'census_2887': '4a33b32c-1a71-47b6-afed-4920726840f0',
#  'census_293': '4a33b32c-1a71-47b6-afed-4920726840f0',
#  'census_329': 'a663dd31-dfb5-4ff7-9bb3-959cb186e889',
#  'census_368': '1b43d707-ad48-456f-8fb8-502f532afa99',
#  'census_379': '1b43d707-ad48-456f-8fb8-502f532afa99',
#  'census_415': '1b43d707-ad48-456f-8fb8-502f532afa99',
#  'census_425': '1b43d707-ad48-456f-8fb8-502f532afa99',
#  'census_452': '1b43d707-ad48-456f-8fb8-502f532afa99',
#  'census_467': '0c146c5d-5f0d-495f-8814-d800f40efbe1',
#  'census_486': '0c146c5d-5f0d-495f-8814-d800f40efbe1',
#  'census_517': '0c146c5d-5f0d-495f-8814-d800f40efbe1',
#  'census_538': '0c146c5d-5f0d-495f-8814-d800f40efbe1',
#  'census_544': '0c146c5d-5f0d-495f-8814-d800f40efbe1',
#  'census_58': '5b19f49c-4a86-40a5-8724-32e1369535be',
#  'census_592': '5b19f49c-4a86-40a5-8724-32e1369535be',
#  'census_654': '5b19f49c-4a86-40a5-8724-32e1369535be',
#  'census_670': 'ddbc7fe6-cc12-4727-b3fd-2f4d9bdb9ae3',
#  'census_677': 'ddbc7fe6-cc12-4727-b3fd-2f4d9bdb9ae3',
#  'census_697': 'ddbc7fe6-cc12-4727-b3fd-2f4d9bdb9ae3',
#  'census_707': 'ddbc7fe6-cc12-4727-b3fd-2f4d9bdb9ae3',
#  'census_71': 'ddbc7fe6-cc12-4727-b3fd-2f4d9bdb9ae3',
#  'census_825': 'd03a4f0b-638a-4c5f-bd02-fac52bb5acb9',
#  'census_838': 'd03a4f0b-638a-4c5f-bd02-fac52bb5acb9',
#  'census_913': 'd03a4f0b-638a-4c5f-bd02-fac52bb5acb9',
#  'census_937': 'd03a4f0b-638a-4c5f-bd02-fac52bb5acb9',
#  'census_947': 'df2d6638-2821-4035-b262-80b639d3214b',
#  'census_972': 'df2d6638-2821-4035-b262-80b639d3214b',
#  'census_1': 'bb3e6e99-08f0-4be3-97ef-b120a27130a7',
#  'census_1003': 'bb3e6e99-08f0-4be3-97ef-b120a27130a7',
#  'census_1006': 'bb3e6e99-08f0-4be3-97ef-b120a27130a7',
#  'census_1062': 'bb3e6e99-08f0-4be3-97ef-b120a27130a7',
#  'census_1066': '1cb1d2d0-09d2-4c30-ab7f-6cf692730ffe',
#  'census_114': '876b816d-9c9e-42c8-bbc7-d11f26951057',
#  'census_1196': '876b816d-9c9e-42c8-bbc7-d11f26951057',
#  'census_1249': '876b816d-9c9e-42c8-bbc7-d11f26951057',
#  'census_1290': '876b816d-9c9e-42c8-bbc7-d11f26951057',
#  'census_1314': '9276ce92-c9c0-4c19-93a5-d10c843ed41c',
#  'census_1354': '9276ce92-c9c0-4c19-93a5-d10c843ed41c',
#  'census_1370': '9276ce92-c9c0-4c19-93a5-d10c843ed41c',
#  'census_1383': '26130f72-e4a9-41fd-9215-ebaae0272aa2',
#  'census_1552': '26130f72-e4a9-41fd-9215-ebaae0272aa2',
#  'census_1579': '26130f72-e4a9-41fd-9215-ebaae0272aa2',
#  'census_1635': '7ff354a9-d4d9-48ce-bd19-a906d8995f5e',
#  'census_1714': '7ff354a9-d4d9-48ce-bd19-a906d8995f5e',
#  'census_1723': '7ff354a9-d4d9-48ce-bd19-a906d8995f5e',
#  'census_175': '5b5be656-976e-4cba-ad99-b0e836569195',
#  'census_1757': '5b5be656-976e-4cba-ad99-b0e836569195',
#  'census_1766': '5b5be656-976e-4cba-ad99-b0e836569195',
#  'census_1788': '5b5be656-976e-4cba-ad99-b0e836569195',
#  'census_180': '9b07f091-dd3f-4e57-ac97-80e71cbf0784',
#  'census_1874': '9b07f091-dd3f-4e57-ac97-80e71cbf0784',
#  'census_1914': '9b07f091-dd3f-4e57-ac97-80e71cbf0784',
#  'census_1998': '9b07f091-dd3f-4e57-ac97-80e71cbf0784',
#  'census_2029': '9b07f091-dd3f-4e57-ac97-80e71cbf0784',
#  'census_2071': '3c0763ce-8e77-4b63-97df-bbaea6119b3a',
#  'census_2096': '3c0763ce-8e77-4b63-97df-bbaea6119b3a',
#  'census_2115': '3c0763ce-8e77-4b63-97df-bbaea6119b3a',
#  'census_2124': '3c0763ce-8e77-4b63-97df-bbaea6119b3a',
#  'census_2126': '3c0763ce-8e77-4b63-97df-bbaea6119b3a',
#  'census_2201': '994f13fb-87c9-4add-b74e-6c9f438c1a11',
#  'census_2214': '55d45c79-1edd-494c-af56-3d2dd7a23072',
#  'census_222': '55d45c79-1edd-494c-af56-3d2dd7a23072',
#  'census_2245': '55d45c79-1edd-494c-af56-3d2dd7a23072',
#  'census_2270': '55d45c79-1edd-494c-af56-3d2dd7a23072',
#  'census_2279': '55d45c79-1edd-494c-af56-3d2dd7a23072',
#  'census_228': 'a7ef3ebc-0d9e-4eb8-afdf-b0f7f476497f',
#  'census_229': 'a7ef3ebc-0d9e-4eb8-afdf-b0f7f476497f',
#  'census_2311': 'a7ef3ebc-0d9e-4eb8-afdf-b0f7f476497f',
#  'census_232': 'a7ef3ebc-0d9e-4eb8-afdf-b0f7f476497f',
#  'census_2353': 'a7ef3ebc-0d9e-4eb8-afdf-b0f7f476497f',
#  'census_2391': '74480094-e98d-411c-8017-6cab25354e0e',
#  'census_240': '74480094-e98d-411c-8017-6cab25354e0e',
#  'census_2457': '74480094-e98d-411c-8017-6cab25354e0e',
#  'census_2464': '0c0f616f-a7ea-45e6-bb42-e11762b79d44',
#  'census_2522': '0c0f616f-a7ea-45e6-bb42-e11762b79d44',
#  'census_2575': '0c0f616f-a7ea-45e6-bb42-e11762b79d44',
#  'census_2602': '0c0f616f-a7ea-45e6-bb42-e11762b79d44',
#  'census_2631': '5f11d986-7c5d-44c6-9580-efaadf4f9d51',
#  'census_2665': '5f11d986-7c5d-44c6-9580-efaadf4f9d51',
#  'census_2668': '5f11d986-7c5d-44c6-9580-efaadf4f9d51',
#  'census_2672': '5f11d986-7c5d-44c6-9580-efaadf4f9d51',
#  'census_2682': '5f11d986-7c5d-44c6-9580-efaadf4f9d51',
#  'census_2699': 'be33610d-9b5d-495c-b0a3-471c00e0a5ac',
#  'census_2812': 'be33610d-9b5d-495c-b0a3-471c00e0a5ac',
#  'census_2850': 'be33610d-9b5d-495c-b0a3-471c00e0a5ac',
#  'census_2890': '7f6866fb-e4e1-4bb4-b509-540a4964b554',
#  'census_2895': '7f6866fb-e4e1-4bb4-b509-540a4964b554',
#  'census_2922': '7f6866fb-e4e1-4bb4-b509-540a4964b554',
#  'census_343': '7f6866fb-e4e1-4bb4-b509-540a4964b554',
#  'census_41': '7f6866fb-e4e1-4bb4-b509-540a4964b554',
#  'census_424': '3ab66c1a-c88a-4873-852d-340de91480f5',
#  'census_480': '3ab66c1a-c88a-4873-852d-340de91480f5',
#  'census_482': '3ab66c1a-c88a-4873-852d-340de91480f5',
#  'census_497': 'd777a2fa-89b5-4280-b202-02411402d092',
#  'census_510': 'd777a2fa-89b5-4280-b202-02411402d092',
#  'census_515': 'd777a2fa-89b5-4280-b202-02411402d092',
#  'census_520': 'd777a2fa-89b5-4280-b202-02411402d092',
#  'census_529': '02d57838-f5ef-45ef-ae5b-19ef0fdd8a5c',
#  'census_575': '8d942d5e-c38a-4c18-bbd8-f868c3a4bbf4',
#  'census_577': '8d942d5e-c38a-4c18-bbd8-f868c3a4bbf4',
#  'census_591': '8d942d5e-c38a-4c18-bbd8-f868c3a4bbf4',
#  'census_614': '8d942d5e-c38a-4c18-bbd8-f868c3a4bbf4',
#  'census_626': '8d942d5e-c38a-4c18-bbd8-f868c3a4bbf4',
#  'census_730': '51f42fa5-2023-47a0-9fbc-08069200fd17',
#  'census_740': 'ba262de5-ec67-40e5-8916-469fa8b16fb2',
#  'census_763': '09b4c440-3d81-4e1f-a1a7-ca6b67d366a3',
#  'census_80': '09b4c440-3d81-4e1f-a1a7-ca6b67d366a3',
#  'census_833': 'f777db7a-6f19-4a84-b344-c0bd7d6ed9bd',
#  'census_952': 'f777db7a-6f19-4a84-b344-c0bd7d6ed9bd',
#  'census_96': 'f777db7a-6f19-4a84-b344-c0bd7d6ed9bd',
#  'census_1012': '0d93d348-43f3-4fec-8049-448d649687bd',
#  'census_1051': '0d93d348-43f3-4fec-8049-448d649687bd',
#  'census_1072': '0d93d348-43f3-4fec-8049-448d649687bd',
#  'census_111': '0a4222a9-3083-4b88-a0fa-ad8ac99daf4e',
#  'census_1120': '0a4222a9-3083-4b88-a0fa-ad8ac99daf4e',
#  'census_1151': '0a4222a9-3083-4b88-a0fa-ad8ac99daf4e',
#  'census_1152': '0a4222a9-3083-4b88-a0fa-ad8ac99daf4e',
#  'census_1155': 'a449d293-d7a4-49ac-81c5-019ff6d05312',
#  'census_1174': 'a449d293-d7a4-49ac-81c5-019ff6d05312',
#  'census_1177': 'a449d293-d7a4-49ac-81c5-019ff6d05312',
#  'census_1191': 'a449d293-d7a4-49ac-81c5-019ff6d05312',
#  'census_1193': '3047c048-0893-416d-8e7b-89a36931b880',
#  'census_1218': 'ba31e55d-512e-4d78-adcd-2c4479acf182',
#  'census_1256': 'ba31e55d-512e-4d78-adcd-2c4479acf182',
#  'census_1257': '1f94ec32-1c7e-4eca-b611-2e896ab03489',
#  'census_1262': '1f94ec32-1c7e-4eca-b611-2e896ab03489',
#  'census_1327': '1f94ec32-1c7e-4eca-b611-2e896ab03489',
#  'census_1336': '1f94ec32-1c7e-4eca-b611-2e896ab03489',
#  'census_1433': '482c2b9b-d7b3-47f6-ba7d-7795bd11637f',
#  'census_1487': '482c2b9b-d7b3-47f6-ba7d-7795bd11637f',
#  'census_150': '482c2b9b-d7b3-47f6-ba7d-7795bd11637f',
#  'census_1638': 'c89859dd-d099-4bce-8586-d8772fda52da',
#  'census_1644': 'c89859dd-d099-4bce-8586-d8772fda52da',
#  'census_1648': 'c89859dd-d099-4bce-8586-d8772fda52da',
#  'census_1697': '0c27c604-cd2b-495b-885f-f2f0f9264027',
#  'census_1698': 'd1edbb26-fd72-4730-8756-0d90f630bd49',
#  'census_1722': 'd1edbb26-fd72-4730-8756-0d90f630bd49',
#  'census_1779': 'd1edbb26-fd72-4730-8756-0d90f630bd49',
#  'census_1782': 'd1edbb26-fd72-4730-8756-0d90f630bd49',
#  'census_1799': 'ddca4632-6fe1-4ce1-bc16-419e6260345c',
#  'census_1805': 'ddca4632-6fe1-4ce1-bc16-419e6260345c',
#  'census_1832': '55625dce-7359-4ab9-a42c-cc46b553b6cd',
#  'census_1842': '906ef6fb-5d5f-459c-9ca9-d5e30d387259',
#  ...}

# %%
new_trips['hid'] = new_trips['pid'].map(person_to_household_map)

# %% [markdown]
# ## Input data after changes

# %%
attributes.head()
# Out:
#           gender   job    occ     inc  age
# pid
# census_0  female  work  white     low   54
# census_1  female  work  white     low   43
# census_2    male  work   blue    high   44
# census_3    male  work   blue     low   34
# census_4    male  work   blue  medium   28

# %%
new_trips.head(10)
# Out:
#    seq         uid       pid                                   hid      hzone  \
# 0    0           0  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 1    1    0_act_to  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 2    2  0_act_from  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 3    3           1  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 4    4    1_act_to  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 5    5  1_act_from  census_0  e265680d-426b-4bba-ab4f-86845f74fecc     Harrow
# 6    0           2  census_1  bb3e6e99-08f0-4be3-97ef-b120a27130a7  Greenwich
# 7    1    2_act_to  census_1  bb3e6e99-08f0-4be3-97ef-b120a27130a7  Greenwich
# 8    2  2_act_from  census_1  bb3e6e99-08f0-4be3-97ef-b120a27130a7  Greenwich
# 9    3           3  census_1  bb3e6e99-08f0-4be3-97ef-b120a27130a7  Greenwich
#
#                   ozone                 dzone     purp mode   tst   tet  freq
# 0                Harrow                Camden     work   pt   444   473  1000
# 1                Camden            Hillingdon  leisure   pt   575   591  1000
# 2            Hillingdon                Harrow  leisure   pt   778   824  1000
# 3                Camden                Harrow     work   pt   890   919  1000
# 4                Harrow             Greenwich   health  car  1086  1147  1000
# 5             Greenwich                Camden   health  car  1175  1338  1000
# 6             Greenwich         Tower Hamlets     work   pt   507   528  1000
# 7         Tower Hamlets  Richmond upon Thames   health   pt   588   611  1000
# 8  Richmond upon Thames             Greenwich   health   pt   859  1053  1000
# 9         Tower Hamlets             Greenwich     work   pt  1065  1086  1000

# %%
new_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17556 entries, 0 to 17555
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   seq     17556 non-null  int64
#  1   uid     17556 non-null  object
#  2   pid     17556 non-null  object
#  3   hid     17250 non-null  object
#  4   hzone   17556 non-null  object
#  5   ozone   17556 non-null  object
#  6   dzone   17556 non-null  object
#  7   purp    17556 non-null  object
#  8   mode    17556 non-null  object
#  9   tst     17556 non-null  object
#  10  tet     17556 non-null  object
#  11  freq    17556 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.6+ MB

# %%
new_trips['purp'].unique(), new_trips['mode'].unique()
# Out:
# (array(['work', 'leisure', 'health', 'shopping', 'education'], dtype=object),
#  array(['pt', 'car', 'bike', 'walk'], dtype=object))

# %%
def print_simple_stats(population):
    """
    Print some simple population statistics.
    """
    time_at_home = 0
    travel_time = 0 
    low_income_central_trips = 0
    high_income_central_trips = 0
    
    for hid, hh in population.households.items():
        for pid, person in hh.people.items():
            freq = person.freq
            
            for p in person.plan:
                if p.act == 'travel':
                    duration = p.duration.seconds * freq / 3600
                    travel_time += duration
                    
                    if p.end_location.area == "Westminster,City of London":
                        if person.attributes['inc'] == "low":
                            low_income_central_trips += freq
                            
                        elif person.attributes['inc'] == "high":
                            high_income_central_trips += freq
                    
                else:  # activity
                    if p.act == 'home':
                        duration = p.duration.seconds * freq / 3600
                        time_at_home += duration
                        
    print(f"Population total time at home: {time_at_home/1000000:.2f} million hours")
    print(f"Population total travel time: {travel_time/1000000:.2f} million hours")
    print(f"Low income trips to Central London: {low_income_central_trips} trips")
    print(f"High income trips to Central London: {high_income_central_trips} trips")

# %% [markdown]
# ## Create the population

# %%
population = parse.load_travel_diary(new_trips, attributes)

# %%
rando_hh_id = list(households_map.keys())[0]
rando_pid_in_hh = list(population.households[rando_hh_id].people)[0]

# %%
population.households[rando_hh_id].people
# Out:
# {'census_1016': <pam.core.Person at 0x119912250>,
#  'census_1043': <pam.core.Person at 0x119916b90>,
#  'census_1197': <pam.core.Person at 0x119916c10>,
#  'census_1247': <pam.core.Person at 0x119919ed0>}

# %%
population.households[rando_hh_id].people[rando_pid_in_hh].plan.print()
# Out:
# 0:	Activity(0 act:home, location:Barking and Dagenham, time:00:00:00 --> 07:21:00, duration:7:21:00)
# 1:	Leg(0 mode:car, area:Barking and Dagenham --> Barking and Dagenham, time:07:21:00 --> 07:30:00, duration:0:09:00)
# 2:	Activity(1 act:home, location:Barking and Dagenham, time:07:30:00 --> 07:45:00, duration:0:15:00)
# 3:	Leg(1 mode:pt, area:Barking and Dagenham --> Enfield, time:07:45:00 --> 08:47:00, duration:1:02:00)
# 4:	Activity(2 act:health, location:Enfield, time:08:47:00 --> 09:58:00, duration:1:11:00)
# 5:	Leg(2 mode:pt, area:Enfield --> Barking and Dagenham, time:09:58:00 --> 15:04:00, duration:5:06:00)
# 6:	Activity(3 act:home, location:Barking and Dagenham, time:15:04:00 --> 16:02:00, duration:0:58:00)
# 7:	Leg(3 mode:car, area:Barking and Dagenham --> Barking and Dagenham, time:16:02:00 --> 16:11:00, duration:0:09:00)
# 8:	Activity(4 act:home, location:Barking and Dagenham, time:16:11:00 --> 19:52:00, duration:3:41:00)
# 9:	Leg(4 mode:car, area:Barking and Dagenham --> Southwark, time:19:52:00 --> 22:29:00, duration:2:37:00)
# 10:	Activity(5 act:shopping, location:Southwark, time:22:29:00 --> 22:48:00, duration:0:19:00)
# 11:	Leg(5 mode:car, area:Southwark --> Barking and Dagenham, time:22:48:00 --> 23:14:00, duration:0:26:00)
# 12:	Activity(6 act:home, location:Barking and Dagenham, time:23:14:00 --> 23:59:00, duration:0:45:00)

# %%
population.households[rando_hh_id].people[rando_pid_in_hh].attributes
# Out:
# {'gender': 'other', 'job': 'work', 'occ': 'white', 'inc': 'low', 'age': 50}

# %%
print_simple_stats(population)
# Out:
# Population total time at home: 34.66 million hours
# Population total travel time: 18.79 million hours
# Low income trips to Central London: 506000 trips
# High income trips to Central London: 541000 trips

# %% [markdown]
# # PAM Simple Policies
#
# Based on [link](https://docs.google.com/spreadsheets/d/1FQMa7dLe2cv1NEZnbu5cZo3v07tKXINwvOaLQYoEp-M/edit#gid=0)

# %%
from pam import modify

def apply_policies(population, policies: list):

    new_population = deepcopy(population) 
    for hid, household in new_population.households.items():
        for policy in policies:
            policy.apply_to(household)
    return new_population

# %% [markdown]
# ## Household Quarantine
#
# Probabilistically apply quarantine to a household (remove all activities - stay at home)

# %% [markdown]
# ### Household-based
#
# If you have a probability of a household having to be quarantined

# %%
policy_household_quarantine_per_household = modify.HouseholdQuarantined(probability=0.01, person_based=False)

# %%
print_simple_stats(apply_policies(population, [policy_household_quarantine_per_household]))
# Out:
# Population total time at home: 34.95 million hours
# Population total travel time: 18.64 million hours
# Low income trips to Central London: 506000 trips
# High income trips to Central London: 538000 trips

# %% [markdown]
# ### Person-based
#
# If you have a probability of any one person living in the household having to be quarantined.
#
# The probability of the household being quarantined is then $1 - (1-P)^n$, where $P$ is the probability any one person being quarantined and $n$ is the number of people in the household; $(1-P)^n$ is the probability of no one having to be quarantined.

# %%
policy_household_quarantine_per_person = modify.HouseholdQuarantined(probability=0.01, person_based=True)

# %%
print_simple_stats(apply_policies(population, [policy_household_quarantine_per_person]))
# Out:
# Population total time at home: 36.06 million hours
# Population total travel time: 18.03 million hours
# Low income trips to Central London: 492000 trips
# High income trips to Central London: 524000 trips

# %% [markdown]
# ## Remove Higher Education
#
# Remove all education activity for persons over age of 17

# %%
def age_condition_over_17(attribute_value):
    return attribute_value > 17

policy_remove_higher_education = modify.RemoveActivity(['education'],
                                                       probability=1, 
                                                       attribute_conditions={'age': age_condition_over_17},
                                                       strict_conditions=True)

# %%
print_simple_stats(apply_policies(population, [policy_remove_higher_education]))
# Out:
# Population total time at home: 36.54 million hours
# Population total travel time: 17.42 million hours
# Low income trips to Central London: 442000 trips
# High income trips to Central London: 463000 trips

# %% [markdown]
# ## Remove Education
#
# Probabilistically remove education activities from a person

# %%
policy_remove_any_education = modify.RemoveActivity(['education'], probability=0.95)

# %%
print_simple_stats(apply_policies(population, [policy_remove_any_education]))
# Out:
# Population total time at home: 36.49 million hours
# Population total travel time: 17.45 million hours
# Low income trips to Central London: 448000 trips
# High income trips to Central London: 462000 trips

# %% [markdown]
# ## Remove Leisure Activities
#
# Remove all leisure activities

# %%
policy_remove_leisure = modify.RemoveActivity(['leisure'], probability=1)

# %%
print_simple_stats(apply_policies(population, [policy_remove_leisure]))
# Out:
# Population total time at home: 41.13 million hours
# Population total travel time: 15.24 million hours
# Low income trips to Central London: 481000 trips
# High income trips to Central London: 517000 trips

# %% [markdown]
# ## Remove Health Activities
#
# Probabilistically remove **individual** health activities from a person

# %%
policy_remove_health = modify.RemoveActivity(['health'], probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_remove_health]))
# Out:
# Population total time at home: 37.79 million hours
# Population total travel time: 17.03 million hours
# Low income trips to Central London: 491000 trips
# High income trips to Central London: 525000 trips

# %% [markdown]
# ## Unemployment/Furlough
#
# Probabilistically remove all work activities from a person

# %%
policy_unemployment_and_furlough = modify.RemoveActivity(['work'], probability=0.1)

# %%
print_simple_stats(apply_policies(population, [policy_unemployment_and_furlough]))
# Out:
# Population total time at home: 35.26 million hours
# Population total travel time: 18.27 million hours
# Low income trips to Central London: 476000 trips
# High income trips to Central London: 516000 trips

# %% [markdown]
# ## Work from Home
#
# Probabilistically remove all work activities from a person

# %%
policy_work_from_home = modify.RemoveActivity(['work'], probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_work_from_home]))
# Out:
# Population total time at home: 37.50 million hours
# Population total travel time: 16.22 million hours
# Low income trips to Central London: 359000 trips
# High income trips to Central London: 383000 trips

# %% [markdown]
# ## Reduced Work Activity
#
# Probabilistically remove **individual** work activities from a person

# %%
policy_reduced_work_activity = modify.RemoveActivity(['work'], probability=0.2)

# %%
print_simple_stats(apply_policies(population, [policy_reduced_work_activity]))
# Out:
# Population total time at home: 35.82 million hours
# Population total travel time: 17.78 million hours
# Low income trips to Central London: 447000 trips
# High income trips to Central London: 478000 trips

# %% [markdown]
# ## Remove Shopping
#
# Probabilistically remove **individual** shopping activities from a person

# %%
policy_remove_shopping = modify.RemoveActivity(['shop'], probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_remove_shopping]))
# Out:
# Population total time at home: 34.66 million hours
# Population total travel time: 18.79 million hours
# Low income trips to Central London: 506000 trips
# High income trips to Central London: 541000 trips
