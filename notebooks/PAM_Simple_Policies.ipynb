# %%
import os
import pandas as pd
import random
from copy import deepcopy
from collections import defaultdict
import geopandas as gp
from matplotlib import pyplot as plt
from pam import parse

path_to_repo = '/Users/.../PythonProjects/pam'

# %% [markdown]
# ## Load Data
# Here we load simple travel diary data of London commuters. This is a very simple 0.1% sample of data about work and education commutes from the 2011 census. Because we're sharing this date - we've aggregated locations to borough level and randomized personal attributes - so don't get too excited about the results.
#
# The data is available in `pam/example_data`.

# %%
trips = pd.read_csv(os.path.join(path_to_repo, 'example_data', 'example_travel_diaries.csv'))
attributes = pd.read_csv(os.path.join(path_to_repo, 'example_data' , 'example_attributes.csv'))
attributes.set_index('pid', inplace=True)

# %%
attributes.head()
# Out:
#           gender   job    occ     inc
# pid
# census_0  female  work  white     low
# census_1  female  work  white     low
# census_2    male  work   blue    high
# census_3    male  work   blue     low
# census_4    male  work   blue  medium

# %%
trips.head()
# Out:
#    uid       pid       hid  seq      hzone          ozone          dzone  \
# 0    0  census_0  census_0    0     Harrow         Harrow         Camden
# 1    1  census_0  census_0    1     Harrow         Camden         Harrow
# 2    2  census_1  census_1    0  Greenwich      Greenwich  Tower Hamlets
# 3    3  census_1  census_1    1  Greenwich  Tower Hamlets      Greenwich
# 4    4  census_2  census_2    0    Croydon        Croydon        Croydon
#
#    purp mode   tst   tet  freq
# 0  work   pt   444   473  1000
# 1  work   pt   890   919  1000
# 2  work   pt   507   528  1000
# 3  work   pt  1065  1086  1000
# 4  work   pt   422   425  1000

# %%
trips['purp'].unique(), trips['mode'].unique()
# Out:
# (array(['work', 'education'], dtype=object),
#  array(['pt', 'car'], dtype=object))

# %% [markdown]
# ## Imagine we had better data...
#
# Conjure up additional data to aid demonstration.
#
# We add:
# - `age` to person attributes
# - activities:
#     - `leisure`
#     - `health`
#     - `shopping`
#     - `escort`
#
# and we put people in shared households based on shared hzone (originally it's one person per household)
#
# **Randomly.**

# %%
import numpy as np

# add age column to attributes
attributes['age'] = [int(a) for a in np.random.normal(40.5, 10, len(attributes))]

# %%
# add some extra activities to trips
zones = list(set(trips['hzone'].unique()) | set(trips['ozone'].unique()) | set(trips['dzone'].unique()))
purp = ['leisure', 'health', 'shopping', 'escort']
mode = ['pt', 'car', 'walk', 'bike']

def enrich_activities(group):
    new_group = pd.DataFrame(columns=group.columns)
    for idx in group.index:
        trip = group.loc[idx, :]
        try:
            next_start = group.loc[idx+1, :]['tst']
        except KeyError:
            next_start = 1439
        new_group = new_group.append(trip)
        # append a random activity
        activity_loc = random.choice(zones)
        activity_purp = random.choice(purp)
        activity_mode = random.choice(mode)

        act_times = [random.randint(trip['tet']+1, next_start-1) for i in range(4)]
        act_times.sort()

        new_group = new_group.append(pd.DataFrame(
            {'uid': ['{}_act_to'.format(trip['uid']), '{}_act_from'.format(trip['uid'])], 
             'pid': [trip['pid'], trip['pid']], 'hid': [trip['hid'], trip['hid']], 
             'seq': [0, 0], 'hzone': [trip['hzone'], trip['hzone']], 'ozone': [trip['dzone'], activity_loc], 
             'dzone': [activity_loc, trip['ozone']], 'purp': [activity_purp, activity_purp], 
             'mode': [activity_mode, activity_mode], 'tst': [act_times[0], act_times[2]], 
             'tet': [act_times[1], act_times[3]], 'freq': [trip['freq'], trip['freq']]}))
    new_group = new_group.reset_index(drop=True)
    new_group = new_group.drop(['seq'], axis=1)
    new_group = new_group.rename_axis('seq').reset_index()
    return new_group

new_trips = trips.groupby('pid').apply(enrich_activities).reset_index(drop=True)

# %%
# generate some households (as opposed one person to a household)
# bunch up people who share the same hzone
import uuid

def bunch_up_people(group):
    group['pid'].unique()
    households = []
    i = 1
    household= []
    h_size = random.randint(1,5)
    for p in group['pid'].unique():
        household.append(p)
        i += 1

        if i>h_size:
            households.append(household)
            h_size = random.randint(1,5)
            household= []
            i = 1

    return dict(zip([str(uuid.uuid4()) for i in range(len(households))], households))

# %%
households_map = {}
households_per_zone = new_trips.groupby('hzone').apply(bunch_up_people)
for idx in households_per_zone.index:
    households_map = {**households_map, **households_per_zone[idx]}

# %%
# ze old switcheroo person to household id
new_keys = []
new_values = []
for key, value in households_map.items():
    for item in value:
        new_keys.append(item)
        new_values.append(key.lower())
person_to_household_map = dict(zip(new_keys, new_values))

# %%
person_to_household_map
# Out:
# {'census_1016': '26d16d0a-3f33-4c68-81e1-95921f035f49',
#  'census_1043': '26d16d0a-3f33-4c68-81e1-95921f035f49',
#  'census_1197': '26d16d0a-3f33-4c68-81e1-95921f035f49',
#  'census_1247': '26d16d0a-3f33-4c68-81e1-95921f035f49',
#  'census_1272': '6578beb2-f8aa-4d5a-bddb-8ea6cf734e65',
#  'census_128': '6578beb2-f8aa-4d5a-bddb-8ea6cf734e65',
#  'census_1281': '6578beb2-f8aa-4d5a-bddb-8ea6cf734e65',
#  'census_1287': '6578beb2-f8aa-4d5a-bddb-8ea6cf734e65',
#  'census_1375': 'eac41418-2041-457d-8d01-2d5a6a3d5e8b',
#  'census_1418': '835a8d44-e04e-47cf-9ca0-e0dd2136d99a',
#  'census_1420': '835a8d44-e04e-47cf-9ca0-e0dd2136d99a',
#  'census_1536': '48b4355c-0421-49ee-9e15-877c9035e7b0',
#  'census_1665': '48b4355c-0421-49ee-9e15-877c9035e7b0',
#  'census_1670': '48b4355c-0421-49ee-9e15-877c9035e7b0',
#  'census_1690': '48b4355c-0421-49ee-9e15-877c9035e7b0',
#  'census_1702': '48b4355c-0421-49ee-9e15-877c9035e7b0',
#  'census_1707': '459103b9-9510-4c4f-b60a-b28cb8f7af7e',
#  'census_1774': '459103b9-9510-4c4f-b60a-b28cb8f7af7e',
#  'census_19': '459103b9-9510-4c4f-b60a-b28cb8f7af7e',
#  'census_1940': '459103b9-9510-4c4f-b60a-b28cb8f7af7e',
#  'census_1986': '5e227d66-c1e2-4cc3-a826-b92f9ad44344',
#  'census_2028': '5e227d66-c1e2-4cc3-a826-b92f9ad44344',
#  'census_2105': '5e227d66-c1e2-4cc3-a826-b92f9ad44344',
#  'census_231': '5e227d66-c1e2-4cc3-a826-b92f9ad44344',
#  'census_1362': '61b7a9c8-211d-47de-b5c6-50c058234e80',
#  'census_1408': '18e30416-8006-47fb-8ba7-79fa4fefdc68',
#  'census_1436': 'd4b8211c-9abe-44d0-88d8-0330efb7a7db',
#  'census_1454': '4474d5d3-6f2e-42b5-8cf6-3f8cf7b6cb1b',
#  'census_1460': '4474d5d3-6f2e-42b5-8cf6-3f8cf7b6cb1b',
#  'census_1485': 'f4a4300e-6324-4c04-8502-26539182d19c',
#  'census_1489': 'f4a4300e-6324-4c04-8502-26539182d19c',
#  'census_1504': 'f4a4300e-6324-4c04-8502-26539182d19c',
#  'census_1527': 'cf9887f3-e2a7-46ef-b8de-ae00a5dbcc5b',
#  'census_1535': 'cf9887f3-e2a7-46ef-b8de-ae00a5dbcc5b',
#  'census_1547': '64fee08c-b22c-431f-9177-2da2ade0db34',
#  'census_1550': '64fee08c-b22c-431f-9177-2da2ade0db34',
#  'census_1551': '64fee08c-b22c-431f-9177-2da2ade0db34',
#  'census_1560': '3b309340-7167-4b92-8154-e6df016115a4',
#  'census_1563': 'e908d57a-45f6-4525-8b43-641f853bf838',
#  'census_1584': 'e908d57a-45f6-4525-8b43-641f853bf838',
#  'census_1612': 'e908d57a-45f6-4525-8b43-641f853bf838',
#  'census_1651': 'e908d57a-45f6-4525-8b43-641f853bf838',
#  'census_1653': 'e908d57a-45f6-4525-8b43-641f853bf838',
#  'census_1666': 'c71b8535-554d-4f69-9210-50e412ab0439',
#  'census_1672': 'c71b8535-554d-4f69-9210-50e412ab0439',
#  'census_1692': 'c71b8535-554d-4f69-9210-50e412ab0439',
#  'census_1694': 'c71b8535-554d-4f69-9210-50e412ab0439',
#  'census_1695': 'c8f15b20-d04d-4853-a374-69d65dc0cb44',
#  'census_1737': 'c7ed394b-893d-4455-85fe-7988cff2840a',
#  'census_1743': 'c7ed394b-893d-4455-85fe-7988cff2840a',
#  'census_1758': 'c7ed394b-893d-4455-85fe-7988cff2840a',
#  'census_1773': 'c7ed394b-893d-4455-85fe-7988cff2840a',
#  'census_1851': '42fbb618-dfab-45ba-9511-acc62179e1a6',
#  'census_1885': '42fbb618-dfab-45ba-9511-acc62179e1a6',
#  'census_1888': '42fbb618-dfab-45ba-9511-acc62179e1a6',
#  'census_1892': '42fbb618-dfab-45ba-9511-acc62179e1a6',
#  'census_1900': '42fbb618-dfab-45ba-9511-acc62179e1a6',
#  'census_1902': 'c41effc3-f36d-4b7d-a58f-50531d9bdc0b',
#  'census_1903': 'c41effc3-f36d-4b7d-a58f-50531d9bdc0b',
#  'census_1912': '7100e642-a151-4bb6-8ded-3187d8ab603b',
#  'census_1950': '7100e642-a151-4bb6-8ded-3187d8ab603b',
#  'census_1984': '7100e642-a151-4bb6-8ded-3187d8ab603b',
#  'census_2034': '911f83c5-4563-47dc-911b-7b7f5dcd55ed',
#  'census_2048': '911f83c5-4563-47dc-911b-7b7f5dcd55ed',
#  'census_2099': '911f83c5-4563-47dc-911b-7b7f5dcd55ed',
#  'census_300': 'a278824c-11a1-4c35-aab2-2b3bcc86516d',
#  'census_332': 'a278824c-11a1-4c35-aab2-2b3bcc86516d',
#  'census_339': 'a93df5fc-6bca-4a9b-8fe1-2da242e39cc8',
#  'census_401': 'a93df5fc-6bca-4a9b-8fe1-2da242e39cc8',
#  'census_404': 'a93df5fc-6bca-4a9b-8fe1-2da242e39cc8',
#  'census_421': 'a93df5fc-6bca-4a9b-8fe1-2da242e39cc8',
#  'census_436': 'c4f73af9-638a-4c73-bdcd-4b614efafa27',
#  'census_45': 'c4f73af9-638a-4c73-bdcd-4b614efafa27',
#  'census_461': 'c4f73af9-638a-4c73-bdcd-4b614efafa27',
#  'census_476': '5576256f-8df6-4a14-945f-dd3fde73e2b4',
#  'census_491': '64475890-7d85-4b65-a499-e3b39fbdfc04',
#  'census_50': '64475890-7d85-4b65-a499-e3b39fbdfc04',
#  'census_525': '64475890-7d85-4b65-a499-e3b39fbdfc04',
#  'census_530': 'a0a1471d-d45d-45da-a877-d9ff2da2fd2f',
#  'census_532': 'a0a1471d-d45d-45da-a877-d9ff2da2fd2f',
#  'census_533': 'a0a1471d-d45d-45da-a877-d9ff2da2fd2f',
#  'census_57': 'a0a1471d-d45d-45da-a877-d9ff2da2fd2f',
#  'census_583': 'a0a1471d-d45d-45da-a877-d9ff2da2fd2f',
#  'census_587': '9aa2171b-c129-421f-889c-035ae993afea',
#  'census_589': '9aa2171b-c129-421f-889c-035ae993afea',
#  'census_601': '9aa2171b-c129-421f-889c-035ae993afea',
#  'census_615': '9aa2171b-c129-421f-889c-035ae993afea',
#  'census_627': '148333d3-ab86-490c-abe2-ff84f317ded9',
#  'census_649': '148333d3-ab86-490c-abe2-ff84f317ded9',
#  'census_665': '148333d3-ab86-490c-abe2-ff84f317ded9',
#  'census_692': '148333d3-ab86-490c-abe2-ff84f317ded9',
#  'census_705': '148333d3-ab86-490c-abe2-ff84f317ded9',
#  'census_760': '7201d892-c247-42c7-a162-16439384e477',
#  'census_762': '7201d892-c247-42c7-a162-16439384e477',
#  'census_768': '7201d892-c247-42c7-a162-16439384e477',
#  'census_776': '7201d892-c247-42c7-a162-16439384e477',
#  'census_795': '7d6366fe-f6e1-42b3-8389-1f07ce45b2db',
#  'census_815': '7d6366fe-f6e1-42b3-8389-1f07ce45b2db',
#  'census_82': 'db860048-8aee-44b5-9c73-18e6569e6ba5',
#  'census_820': 'db860048-8aee-44b5-9c73-18e6569e6ba5',
#  'census_839': 'db860048-8aee-44b5-9c73-18e6569e6ba5',
#  'census_87': 'b2a8a5c9-e9d2-4555-a7df-f1da221ca94c',
#  'census_882': 'b2a8a5c9-e9d2-4555-a7df-f1da221ca94c',
#  'census_92': 'b2a8a5c9-e9d2-4555-a7df-f1da221ca94c',
#  'census_956': '04f0ce94-1dc9-4bf7-aefc-96ec5c28ed8a',
#  'census_968': '04f0ce94-1dc9-4bf7-aefc-96ec5c28ed8a',
#  'census_978': '617818e0-5607-42f4-bdf0-ac2ab154ea59',
#  'census_1011': '04eaad79-a34d-4db2-80ec-29b54f2236c4',
#  'census_1045': '70dea024-0f62-4a41-9458-449cb5f6f0ad',
#  'census_1057': '70dea024-0f62-4a41-9458-449cb5f6f0ad',
#  'census_1073': '70dea024-0f62-4a41-9458-449cb5f6f0ad',
#  'census_1144': '70dea024-0f62-4a41-9458-449cb5f6f0ad',
#  'census_1162': '6615a847-6889-41f9-a360-870e5758454d',
#  'census_1171': '6615a847-6889-41f9-a360-870e5758454d',
#  'census_1199': '6615a847-6889-41f9-a360-870e5758454d',
#  'census_120': '6615a847-6889-41f9-a360-870e5758454d',
#  'census_1205': '6615a847-6889-41f9-a360-870e5758454d',
#  'census_1253': 'd2e42d9e-0b07-4f75-ba5a-edc4dedad3fb',
#  'census_1278': 'd2e42d9e-0b07-4f75-ba5a-edc4dedad3fb',
#  'census_1280': '2e0be75a-e1b8-4cd0-8738-a6826258b3fc',
#  'census_133': '655496db-2de9-4b33-8db2-14422ceaf639',
#  'census_1364': '655496db-2de9-4b33-8db2-14422ceaf639',
#  'census_1414': '655496db-2de9-4b33-8db2-14422ceaf639',
#  'census_144': '705681b1-f5b7-48e2-bd25-5bbef9eeb934',
#  'census_145': '705681b1-f5b7-48e2-bd25-5bbef9eeb934',
#  'census_1474': '705681b1-f5b7-48e2-bd25-5bbef9eeb934',
#  'census_1499': '705681b1-f5b7-48e2-bd25-5bbef9eeb934',
#  'census_1544': '705681b1-f5b7-48e2-bd25-5bbef9eeb934',
#  'census_1568': '4b826a69-c146-4e71-9dcd-f84d421378b3',
#  'census_1576': '4b826a69-c146-4e71-9dcd-f84d421378b3',
#  'census_1600': '4b826a69-c146-4e71-9dcd-f84d421378b3',
#  'census_1603': '4b826a69-c146-4e71-9dcd-f84d421378b3',
#  'census_1667': '4b826a69-c146-4e71-9dcd-f84d421378b3',
#  'census_1734': '0cd2f699-4719-4f14-8b21-a6983526672d',
#  'census_1833': '0cd2f699-4719-4f14-8b21-a6983526672d',
#  'census_191': '0cd2f699-4719-4f14-8b21-a6983526672d',
#  'census_1913': 'd9e43565-f514-44ec-8ae4-5f0afb26b6e2',
#  'census_1999': 'd9e43565-f514-44ec-8ae4-5f0afb26b6e2',
#  'census_2018': '0de74cb6-48ac-4c6c-80e8-05963a61fe38',
#  'census_2020': '0de74cb6-48ac-4c6c-80e8-05963a61fe38',
#  'census_2021': '0de74cb6-48ac-4c6c-80e8-05963a61fe38',
#  'census_2042': 'e160bdb6-0f66-4c9a-8456-b4842464a7fa',
#  'census_208': 'e160bdb6-0f66-4c9a-8456-b4842464a7fa',
#  'census_2082': 'e160bdb6-0f66-4c9a-8456-b4842464a7fa',
#  'census_2110': 'e160bdb6-0f66-4c9a-8456-b4842464a7fa',
#  'census_2155': '645b0c05-e134-4b75-9f64-8a063143194d',
#  'census_2314': '645b0c05-e134-4b75-9f64-8a063143194d',
#  'census_2332': '645b0c05-e134-4b75-9f64-8a063143194d',
#  'census_2358': '645b0c05-e134-4b75-9f64-8a063143194d',
#  'census_2369': '645b0c05-e134-4b75-9f64-8a063143194d',
#  'census_2374': '8c79f376-a02d-460f-bce7-5b37a53adb61',
#  'census_2377': '8c79f376-a02d-460f-bce7-5b37a53adb61',
#  'census_2488': '8c79f376-a02d-460f-bce7-5b37a53adb61',
#  'census_2492': '8c79f376-a02d-460f-bce7-5b37a53adb61',
#  'census_2495': '2c9dfe69-00cf-4a31-aae0-37dce661bbd0',
#  'census_2561': '2c9dfe69-00cf-4a31-aae0-37dce661bbd0',
#  'census_2571': '2c9dfe69-00cf-4a31-aae0-37dce661bbd0',
#  'census_2610': '2c9dfe69-00cf-4a31-aae0-37dce661bbd0',
#  'census_262': '2c9dfe69-00cf-4a31-aae0-37dce661bbd0',
#  'census_2640': 'bccd44a4-7e0b-463a-83f6-e118d3a778b4',
#  'census_2663': 'bccd44a4-7e0b-463a-83f6-e118d3a778b4',
#  'census_2666': 'bccd44a4-7e0b-463a-83f6-e118d3a778b4',
#  'census_2827': 'a9ef08d0-4e6a-421d-8a6a-3d1ef186cff8',
#  'census_2873': 'a9ef08d0-4e6a-421d-8a6a-3d1ef186cff8',
#  'census_2874': '59b4c0a5-ca09-455d-9ebc-a60c91575a64',
#  'census_308': 'bbaf1f04-39a2-4bf8-a4da-735e9f1ff1a8',
#  'census_359': 'bbaf1f04-39a2-4bf8-a4da-735e9f1ff1a8',
#  'census_363': 'ed035c3c-fb62-4e9a-8684-369cc5b4a7bb',
#  'census_369': 'ed035c3c-fb62-4e9a-8684-369cc5b4a7bb',
#  'census_392': 'ed035c3c-fb62-4e9a-8684-369cc5b4a7bb',
#  'census_484': 'ed035c3c-fb62-4e9a-8684-369cc5b4a7bb',
#  'census_590': 'f62338b2-f0f6-4cc1-8eb3-017b72b1f401',
#  'census_625': 'fd8bbfee-6ee4-42ac-aa59-ad51ee7030ba',
#  'census_663': 'fd8bbfee-6ee4-42ac-aa59-ad51ee7030ba',
#  'census_675': 'fd8bbfee-6ee4-42ac-aa59-ad51ee7030ba',
#  'census_701': 'fd8bbfee-6ee4-42ac-aa59-ad51ee7030ba',
#  'census_738': 'fd8bbfee-6ee4-42ac-aa59-ad51ee7030ba',
#  'census_74': 'e420a6b2-6cbb-4eab-acd4-0dc90413f204',
#  'census_769': 'e420a6b2-6cbb-4eab-acd4-0dc90413f204',
#  'census_851': 'e420a6b2-6cbb-4eab-acd4-0dc90413f204',
#  'census_921': 'e420a6b2-6cbb-4eab-acd4-0dc90413f204',
#  'census_928': '55595845-a2cd-4656-a767-5e199a26f5c6',
#  'census_949': '55595845-a2cd-4656-a767-5e199a26f5c6',
#  'census_1020': '2b30e6c2-87fc-4387-aa8e-493d855dd670',
#  'census_1076': '2b30e6c2-87fc-4387-aa8e-493d855dd670',
#  'census_110': '2b30e6c2-87fc-4387-aa8e-493d855dd670',
#  'census_1109': 'a7afb998-190e-435f-8814-773aabaf3a4a',
#  'census_2795': '34a7c753-3b7b-4aaf-9aa5-243348b1abb9',
#  'census_2853': 'bb64f2cf-6127-4685-a967-6784c3c90b7e',
#  'census_297': 'bb64f2cf-6127-4685-a967-6784c3c90b7e',
#  'census_322': 'a2a7bf8a-6207-4a78-8e76-04a856830fd9',
#  'census_341': 'a2a7bf8a-6207-4a78-8e76-04a856830fd9',
#  'census_38': 'a2a7bf8a-6207-4a78-8e76-04a856830fd9',
#  'census_393': 'a2a7bf8a-6207-4a78-8e76-04a856830fd9',
#  'census_407': 'a2a7bf8a-6207-4a78-8e76-04a856830fd9',
#  'census_420': '83022366-23be-4fa5-8e5f-50a75fbe279d',
#  'census_431': '83022366-23be-4fa5-8e5f-50a75fbe279d',
#  'census_456': '83022366-23be-4fa5-8e5f-50a75fbe279d',
#  'census_471': 'f1fe0ed3-835a-49fa-8530-e7d112ab8590',
#  'census_509': 'f1fe0ed3-835a-49fa-8530-e7d112ab8590',
#  'census_511': '737bd50a-7fbf-4f1b-849a-2c9bec1f3120',
#  'census_513': '737bd50a-7fbf-4f1b-849a-2c9bec1f3120',
#  'census_523': '737bd50a-7fbf-4f1b-849a-2c9bec1f3120',
#  'census_750': 'cda727ca-1f1a-4140-9da2-ccc444893b57',
#  'census_765': 'cda727ca-1f1a-4140-9da2-ccc444893b57',
#  'census_814': 'd164e9a7-9ca9-4882-b3c3-2a18082d76dc',
#  'census_817': 'd164e9a7-9ca9-4882-b3c3-2a18082d76dc',
#  'census_827': 'd164e9a7-9ca9-4882-b3c3-2a18082d76dc',
#  'census_849': 'd164e9a7-9ca9-4882-b3c3-2a18082d76dc',
#  'census_861': 'd164e9a7-9ca9-4882-b3c3-2a18082d76dc',
#  'census_894': 'eb1183e3-255b-46f0-b61b-a1a3a886d819',
#  'census_934': 'a44fd1a9-34f8-4bf0-b4ac-13911fd0cab0',
#  'census_1013': '01e70246-e8db-43e6-a4ee-42202168701d',
#  'census_1040': '01e70246-e8db-43e6-a4ee-42202168701d',
#  'census_1047': '01e70246-e8db-43e6-a4ee-42202168701d',
#  'census_1048': '01e70246-e8db-43e6-a4ee-42202168701d',
#  'census_112': '01e70246-e8db-43e6-a4ee-42202168701d',
#  'census_115': 'cdf482b9-4435-4882-a78a-aa7c4bad700e',
#  'census_1208': 'cdf482b9-4435-4882-a78a-aa7c4bad700e',
#  'census_126': 'cdf482b9-4435-4882-a78a-aa7c4bad700e',
#  'census_1268': 'dce89ccd-d4ff-4b8e-a670-a5c4b2814de1',
#  'census_1283': 'dce89ccd-d4ff-4b8e-a670-a5c4b2814de1',
#  'census_1301': 'dce89ccd-d4ff-4b8e-a670-a5c4b2814de1',
#  'census_1304': 'dce89ccd-d4ff-4b8e-a670-a5c4b2814de1',
#  'census_1309': '22b98533-f5be-4a5b-a7b5-c66df9a5a0fe',
#  'census_1357': '22b98533-f5be-4a5b-a7b5-c66df9a5a0fe',
#  'census_1381': '22b98533-f5be-4a5b-a7b5-c66df9a5a0fe',
#  'census_1387': 'da234de7-54d8-4f54-b45a-0d4e74e0ad51',
#  'census_1409': 'da234de7-54d8-4f54-b45a-0d4e74e0ad51',
#  'census_1458': '2421935a-3dec-4b9a-a199-ddef32275884',
#  'census_1481': '2421935a-3dec-4b9a-a199-ddef32275884',
#  'census_1501': '2421935a-3dec-4b9a-a199-ddef32275884',
#  'census_1534': '7d6ca7e7-0535-4a2b-a724-7ebfcd19931c',
#  'census_1569': '7d6ca7e7-0535-4a2b-a724-7ebfcd19931c',
#  'census_1642': '7d6ca7e7-0535-4a2b-a724-7ebfcd19931c',
#  'census_1645': '1dd76231-9740-4b09-927f-8b85b1bf3d3d',
#  'census_1718': '1dd76231-9740-4b09-927f-8b85b1bf3d3d',
#  'census_1725': 'f0a657ef-8b43-4530-8ff1-de074e7ae765',
#  'census_1769': '28f41678-259c-4f23-8ecc-111f8d97c500',
#  'census_1786': '28f41678-259c-4f23-8ecc-111f8d97c500',
#  'census_1818': '28f41678-259c-4f23-8ecc-111f8d97c500',
#  'census_1882': '28f41678-259c-4f23-8ecc-111f8d97c500',
#  'census_1890': '28f41678-259c-4f23-8ecc-111f8d97c500',
#  'census_1931': 'b22dc6cb-5927-44ce-8131-b3483a458e83',
#  'census_1941': 'b22dc6cb-5927-44ce-8131-b3483a458e83',
#  'census_1949': '80d3cc44-3f70-4ec1-91f9-ff22f09cf380',
#  'census_1978': '80d3cc44-3f70-4ec1-91f9-ff22f09cf380',
#  'census_2090': '80d3cc44-3f70-4ec1-91f9-ff22f09cf380',
#  'census_2154': 'bb51d3d7-df7c-4a5b-acff-0d50b6d33cf7',
#  'census_2161': 'bb51d3d7-df7c-4a5b-acff-0d50b6d33cf7',
#  'census_2162': '679c1cf1-ebea-4cc1-8535-58b84edeaa06',
#  'census_2165': '679c1cf1-ebea-4cc1-8535-58b84edeaa06',
#  'census_2199': '679c1cf1-ebea-4cc1-8535-58b84edeaa06',
#  'census_221': '0f4a132b-d3d1-482d-a565-2e289f15e988',
#  'census_2219': '0f4a132b-d3d1-482d-a565-2e289f15e988',
#  'census_2262': '0f4a132b-d3d1-482d-a565-2e289f15e988',
#  'census_2267': '0f4a132b-d3d1-482d-a565-2e289f15e988',
#  'census_2282': 'a9df04d0-33df-46ec-a70e-4c0de397295d',
#  'census_2342': 'a9df04d0-33df-46ec-a70e-4c0de397295d',
#  'census_2395': 'a9df04d0-33df-46ec-a70e-4c0de397295d',
#  'census_2570': 'a9df04d0-33df-46ec-a70e-4c0de397295d',
#  'census_2606': 'a9df04d0-33df-46ec-a70e-4c0de397295d',
#  'census_2637': '15f888ba-8b3a-471e-a8b4-50f030ddf528',
#  'census_2639': '15f888ba-8b3a-471e-a8b4-50f030ddf528',
#  'census_2642': '441e101a-0bdc-4e63-8778-4d57e7b44357',
#  'census_2647': 'ee9baef4-944f-4d5e-aeb7-52a9f577f292',
#  'census_2679': 'ee9baef4-944f-4d5e-aeb7-52a9f577f292',
#  'census_2683': 'ee9baef4-944f-4d5e-aeb7-52a9f577f292',
#  'census_27': 'ee9baef4-944f-4d5e-aeb7-52a9f577f292',
#  'census_2721': '7e2ef706-004f-4346-bda2-b8911fa55321',
#  'census_2761': 'aca1d909-4ac4-4c31-b882-25dc93e3c258',
#  'census_2769': 'aca1d909-4ac4-4c31-b882-25dc93e3c258',
#  'census_2817': '8558f61e-391f-4e17-992c-26424c68dfa7',
#  'census_2830': '20f2a904-7c20-4046-bed3-8bc2d938d8f3',
#  'census_2847': '20f2a904-7c20-4046-bed3-8bc2d938d8f3',
#  'census_2855': '20f2a904-7c20-4046-bed3-8bc2d938d8f3',
#  'census_2892': '20f2a904-7c20-4046-bed3-8bc2d938d8f3',
#  'census_296': 'aaa562e1-ced8-4be2-b539-ef825fe42be9',
#  'census_317': 'aaa562e1-ced8-4be2-b539-ef825fe42be9',
#  'census_353': 'aaa562e1-ced8-4be2-b539-ef825fe42be9',
#  'census_355': 'aaa562e1-ced8-4be2-b539-ef825fe42be9',
#  'census_386': '2e34788a-c8ff-4fe0-a6ed-55cebb6d4cc5',
#  'census_387': '2e34788a-c8ff-4fe0-a6ed-55cebb6d4cc5',
#  'census_406': '2e34788a-c8ff-4fe0-a6ed-55cebb6d4cc5',
#  'census_433': 'dc41edb5-e800-4878-8484-ecfef78642b3',
#  'census_449': 'dc41edb5-e800-4878-8484-ecfef78642b3',
#  'census_465': 'cab80a81-fcab-45da-b709-085e5516ebe2',
#  'census_474': 'cab80a81-fcab-45da-b709-085e5516ebe2',
#  'census_493': 'cab80a81-fcab-45da-b709-085e5516ebe2',
#  'census_531': 'cab80a81-fcab-45da-b709-085e5516ebe2',
#  'census_554': 'a179bb46-1046-4c74-b876-8f85933aad21',
#  'census_597': 'a179bb46-1046-4c74-b876-8f85933aad21',
#  'census_605': 'a179bb46-1046-4c74-b876-8f85933aad21',
#  'census_606': 'a179bb46-1046-4c74-b876-8f85933aad21',
#  'census_639': 'ed5d3029-f5de-452c-8713-bccdc52ad0d7',
#  'census_65': '5ea81f76-eaae-45be-9188-2503dd6d34f3',
#  'census_657': '5ea81f76-eaae-45be-9188-2503dd6d34f3',
#  'census_661': 'df0c0050-ed00-4a6f-aa07-07fbee819cfb',
#  'census_67': '24143f61-8fea-4885-b794-7da0e64c985a',
#  'census_695': 'a01caf1f-1bee-41af-bd7f-0f4f5bd4a141',
#  'census_714': 'a01caf1f-1bee-41af-bd7f-0f4f5bd4a141',
#  'census_716': 'd20db785-6360-4479-8a3d-3a2e128b7f39',
#  'census_72': 'd20db785-6360-4479-8a3d-3a2e128b7f39',
#  'census_758': 'd20db785-6360-4479-8a3d-3a2e128b7f39',
#  'census_77': 'd20db785-6360-4479-8a3d-3a2e128b7f39',
#  'census_81': 'deb85763-e733-435d-b1ee-49b0dcf0fe3c',
#  'census_845': 'deb85763-e733-435d-b1ee-49b0dcf0fe3c',
#  'census_847': 'deb85763-e733-435d-b1ee-49b0dcf0fe3c',
#  'census_853': 'deb85763-e733-435d-b1ee-49b0dcf0fe3c',
#  'census_856': '2fba8dda-7b16-4903-8b6a-552151a6fd27',
#  'census_920': '2fba8dda-7b16-4903-8b6a-552151a6fd27',
#  'census_967': '9e9a260c-2fc8-4e85-a71c-454cbb142394',
#  'census_977': '9e9a260c-2fc8-4e85-a71c-454cbb142394',
#  'census_103': '45be5714-a4df-4f00-b3d6-8b5024644d1c',
#  'census_1052': '45be5714-a4df-4f00-b3d6-8b5024644d1c',
#  'census_1064': '45be5714-a4df-4f00-b3d6-8b5024644d1c',
#  'census_1070': '45be5714-a4df-4f00-b3d6-8b5024644d1c',
#  'census_1115': '45be5714-a4df-4f00-b3d6-8b5024644d1c',
#  'census_1137': '005073bc-2a4f-4a21-84f9-ff4928c7666e',
#  'census_1263': '005073bc-2a4f-4a21-84f9-ff4928c7666e',
#  'census_1267': '005073bc-2a4f-4a21-84f9-ff4928c7666e',
#  'census_1298': '005073bc-2a4f-4a21-84f9-ff4928c7666e',
#  'census_1319': '005073bc-2a4f-4a21-84f9-ff4928c7666e',
#  'census_1346': '87b11de0-d2f8-419b-967f-07f28e1f79b8',
#  'census_1388': '87b11de0-d2f8-419b-967f-07f28e1f79b8',
#  'census_1391': '87b11de0-d2f8-419b-967f-07f28e1f79b8',
#  'census_1415': '87b11de0-d2f8-419b-967f-07f28e1f79b8',
#  'census_1440': '87b11de0-d2f8-419b-967f-07f28e1f79b8',
#  'census_1564': '33472a39-d7d9-41e2-ba6b-81c6fea214fb',
#  'census_1605': '2e595d65-d43f-4346-af03-f2d7818abbf9',
#  'census_1628': '2e595d65-d43f-4346-af03-f2d7818abbf9',
#  'census_1664': '2e595d65-d43f-4346-af03-f2d7818abbf9',
#  'census_1704': '2e595d65-d43f-4346-af03-f2d7818abbf9',
#  'census_1705': '2e595d65-d43f-4346-af03-f2d7818abbf9',
#  'census_1736': 'f5f6acd8-118c-4302-830f-5f10ef6d0391',
#  'census_1762': '01148ecd-3106-4088-a165-94d9b74c0b04',
#  'census_1781': '01148ecd-3106-4088-a165-94d9b74c0b04',
#  'census_1826': '01148ecd-3106-4088-a165-94d9b74c0b04',
#  'census_184': '01148ecd-3106-4088-a165-94d9b74c0b04',
#  'census_1845': '01148ecd-3106-4088-a165-94d9b74c0b04',
#  'census_1895': '9a1fa3a2-b8b1-4f68-90b9-eaf7caf726e3',
#  'census_1934': 'e2d7eae8-f2b6-4084-975d-3e2cd209b53f',
#  'census_2010': '1fcdd056-d3d4-4807-9592-32059612d71c',
#  'census_2058': '1fcdd056-d3d4-4807-9592-32059612d71c',
#  'census_2086': '1fcdd056-d3d4-4807-9592-32059612d71c',
#  'census_2098': '1fcdd056-d3d4-4807-9592-32059612d71c',
#  'census_2108': 'd38b5b89-1892-4081-a642-506d4edbb804',
#  'census_2135': 'd38b5b89-1892-4081-a642-506d4edbb804',
#  'census_2152': 'd38b5b89-1892-4081-a642-506d4edbb804',
#  'census_2232': 'd38b5b89-1892-4081-a642-506d4edbb804',
#  'census_2257': '930d2212-b229-4117-b6e6-3ef80fcdefd8',
#  'census_2382': '930d2212-b229-4117-b6e6-3ef80fcdefd8',
#  'census_2385': '930d2212-b229-4117-b6e6-3ef80fcdefd8',
#  'census_2427': '930d2212-b229-4117-b6e6-3ef80fcdefd8',
#  'census_2476': 'd813074d-de96-4519-966d-97999a3ed27c',
#  'census_2532': 'd813074d-de96-4519-966d-97999a3ed27c',
#  'census_2536': 'd813074d-de96-4519-966d-97999a3ed27c',
#  'census_2566': 'd813074d-de96-4519-966d-97999a3ed27c',
#  'census_2567': '3a943915-bd34-4b74-b24a-4db3ab7a386a',
#  'census_258': '3a943915-bd34-4b74-b24a-4db3ab7a386a',
#  'census_2619': '3a943915-bd34-4b74-b24a-4db3ab7a386a',
#  'census_2671': '3a943915-bd34-4b74-b24a-4db3ab7a386a',
#  'census_2739': '0e6ea644-b9cf-4bac-b4e2-b93d9e97e3b9',
#  'census_2775': '0e6ea644-b9cf-4bac-b4e2-b93d9e97e3b9',
#  'census_2826': 'bc8bbedb-b4c9-4836-9c38-31bceb05f88e',
#  'census_283': 'bc8bbedb-b4c9-4836-9c38-31bceb05f88e',
#  'census_288': 'bc8bbedb-b4c9-4836-9c38-31bceb05f88e',
#  'census_30': '41882049-b8dc-4c84-b0db-2d59f29e68ef',
#  'census_330': '41882049-b8dc-4c84-b0db-2d59f29e68ef',
#  'census_333': '41882049-b8dc-4c84-b0db-2d59f29e68ef',
#  'census_381': '41882049-b8dc-4c84-b0db-2d59f29e68ef',
#  'census_409': '41882049-b8dc-4c84-b0db-2d59f29e68ef',
#  'census_478': '27f55f24-8e3e-486e-a2b1-30d8c7d07613',
#  'census_489': '27f55f24-8e3e-486e-a2b1-30d8c7d07613',
#  'census_49': '744930ee-4173-4861-927e-1d41aca27fcb',
#  'census_63': '744930ee-4173-4861-927e-1d41aca27fcb',
#  'census_636': '744930ee-4173-4861-927e-1d41aca27fcb',
#  'census_646': '744930ee-4173-4861-927e-1d41aca27fcb',
#  'census_699': '744930ee-4173-4861-927e-1d41aca27fcb',
#  'census_726': 'f23088ca-716d-49a6-9e53-488f20c44323',
#  'census_811': 'f23088ca-716d-49a6-9e53-488f20c44323',
#  'census_840': 'f23088ca-716d-49a6-9e53-488f20c44323',
#  'census_883': 'f23088ca-716d-49a6-9e53-488f20c44323',
#  'census_897': '14dff603-0937-4ff7-837e-310bfa296f89',
#  'census_911': '14dff603-0937-4ff7-837e-310bfa296f89',
#  'census_93': '14dff603-0937-4ff7-837e-310bfa296f89',
#  'census_10': '3f2892bc-14ac-4cca-b1a6-4cb109d71534',
#  'census_1009': '2889fe22-8c30-437b-b224-ad212424728d',
#  'census_1050': '2889fe22-8c30-437b-b224-ad212424728d',
#  'census_1054': '2889fe22-8c30-437b-b224-ad212424728d',
#  'census_1097': '2889fe22-8c30-437b-b224-ad212424728d',
#  'census_1098': '2889fe22-8c30-437b-b224-ad212424728d',
#  'census_1128': 'ac0ca0ab-0434-4be5-bdf3-5cb314581a3c',
#  'census_1172': 'ac0ca0ab-0434-4be5-bdf3-5cb314581a3c',
#  'census_1176': 'ac0ca0ab-0434-4be5-bdf3-5cb314581a3c',
#  'census_1179': '0cc97728-f457-46eb-a8df-608863b9f3e0',
#  'census_12': '0cc97728-f457-46eb-a8df-608863b9f3e0',
#  'census_1210': 'b0976652-20a1-479d-996a-c139a85f86b0',
#  'census_1227': '1eb31855-35ec-41e0-82c7-3fd6f64d25a8',
#  'census_1244': '1eb31855-35ec-41e0-82c7-3fd6f64d25a8',
#  'census_1246': '578b4bc7-15fd-458a-8cb6-c35bbd39a2d1',
#  'census_1270': '578b4bc7-15fd-458a-8cb6-c35bbd39a2d1',
#  'census_1274': '578b4bc7-15fd-458a-8cb6-c35bbd39a2d1',
#  'census_1343': '578b4bc7-15fd-458a-8cb6-c35bbd39a2d1',
#  'census_1389': 'f1cac51d-cc96-47c0-b120-c27bb6a61701',
#  'census_141': 'f1cac51d-cc96-47c0-b120-c27bb6a61701',
#  'census_1428': 'f1cac51d-cc96-47c0-b120-c27bb6a61701',
#  'census_1442': 'f1cac51d-cc96-47c0-b120-c27bb6a61701',
#  'census_147': '68ec3c99-5d19-4a12-9624-e7706779ea5b',
#  'census_1483': '68ec3c99-5d19-4a12-9624-e7706779ea5b',
#  'census_1486': 'dc3bd1af-0d87-45b6-84be-b549292ee780',
#  'census_151': 'dc3bd1af-0d87-45b6-84be-b549292ee780',
#  'census_1522': 'dc3bd1af-0d87-45b6-84be-b549292ee780',
#  'census_1572': 'dc3bd1af-0d87-45b6-84be-b549292ee780',
#  'census_1582': '5d48e0f7-9484-4ee0-a888-3c99699323cc',
#  'census_162': '5d48e0f7-9484-4ee0-a888-3c99699323cc',
#  'census_1630': 'a1199307-2905-4373-b576-cb08eef121a9',
#  'census_1641': 'a1199307-2905-4373-b576-cb08eef121a9',
#  'census_1675': '3d60da50-a8a6-427d-934c-84ba8654ffce',
#  'census_171': '22cc1fab-f7b6-413c-8737-becebb5cde11',
#  'census_1716': '22cc1fab-f7b6-413c-8737-becebb5cde11',
#  'census_1735': '22cc1fab-f7b6-413c-8737-becebb5cde11',
#  'census_1741': '22cc1fab-f7b6-413c-8737-becebb5cde11',
#  'census_178': '41973852-cd6a-4ac4-8b9a-ce3d20557c14',
#  'census_1800': '41973852-cd6a-4ac4-8b9a-ce3d20557c14',
#  'census_1807': '41973852-cd6a-4ac4-8b9a-ce3d20557c14',
#  'census_1815': '41973852-cd6a-4ac4-8b9a-ce3d20557c14',
#  'census_1821': '0a3f70dd-30f5-4219-9790-a2d54c218076',
#  'census_1855': '0a3f70dd-30f5-4219-9790-a2d54c218076',
#  'census_1896': '0a3f70dd-30f5-4219-9790-a2d54c218076',
#  'census_1897': '0a3f70dd-30f5-4219-9790-a2d54c218076',
#  'census_1898': '0a3f70dd-30f5-4219-9790-a2d54c218076',
#  'census_1908': 'c830be59-acea-49f3-8bb2-d0e584a05254',
#  'census_1918': 'c830be59-acea-49f3-8bb2-d0e584a05254',
#  'census_1921': 'c830be59-acea-49f3-8bb2-d0e584a05254',
#  'census_2': 'c830be59-acea-49f3-8bb2-d0e584a05254',
#  'census_2006': '25c5bd60-109a-4117-b63d-f0258b1f8cbd',
#  'census_201': '25c5bd60-109a-4117-b63d-f0258b1f8cbd',
#  'census_2040': '25c5bd60-109a-4117-b63d-f0258b1f8cbd',
#  'census_2046': '62d2f010-b14a-41c1-9a15-cd0b7e963cdc',
#  'census_206': '62d2f010-b14a-41c1-9a15-cd0b7e963cdc',
#  'census_2062': '0eeb7ce8-ea3f-43e0-b52c-4fb9bc68b88d',
#  'census_2075': '0eeb7ce8-ea3f-43e0-b52c-4fb9bc68b88d',
#  'census_2077': '0eeb7ce8-ea3f-43e0-b52c-4fb9bc68b88d',
#  'census_210': 'e1fe3530-4d24-441d-8d53-31a9c9a7791b',
#  'census_2122': 'e1fe3530-4d24-441d-8d53-31a9c9a7791b',
#  'census_2136': 'e1fe3530-4d24-441d-8d53-31a9c9a7791b',
#  'census_2142': 'f9913aa4-f0a0-4173-b24a-382d642d72e2',
#  'census_2179': 'f9913aa4-f0a0-4173-b24a-382d642d72e2',
#  'census_2188': 'f9913aa4-f0a0-4173-b24a-382d642d72e2',
#  'census_219': 'f9913aa4-f0a0-4173-b24a-382d642d72e2',
#  'census_2222': 'd1f147c3-d3d7-4847-847b-77563a91d1bf',
#  'census_2235': 'd1f147c3-d3d7-4847-847b-77563a91d1bf',
#  'census_2269': '35892a52-8847-4102-90ae-8d910f3a63a7',
#  'census_2286': '35892a52-8847-4102-90ae-8d910f3a63a7',
#  'census_2329': '35892a52-8847-4102-90ae-8d910f3a63a7',
#  'census_2333': 'ac986297-b2f6-49c0-ac11-f13ab25e25e2',
#  'census_2357': 'ac986297-b2f6-49c0-ac11-f13ab25e25e2',
#  'census_238': '9ed50d45-dc58-4f4b-9956-016b17f69f3c',
#  'census_2398': '135da151-c665-4055-bc1e-2f98ed8a5ace',
#  'census_2407': 'd6044f24-a4f0-42aa-920e-7745c72e867b',
#  'census_2423': 'd6044f24-a4f0-42aa-920e-7745c72e867b',
#  'census_2430': 'd6044f24-a4f0-42aa-920e-7745c72e867b',
#  'census_2433': 'fbeb8bf3-f561-42d6-b549-c5f3f266891e',
#  'census_2438': 'fbeb8bf3-f561-42d6-b549-c5f3f266891e',
#  'census_2449': '65b62dec-a43a-4045-b4a5-b740ffb5f64d',
#  'census_2452': '65b62dec-a43a-4045-b4a5-b740ffb5f64d',
#  'census_2463': '65b62dec-a43a-4045-b4a5-b740ffb5f64d',
#  'census_2474': '65b62dec-a43a-4045-b4a5-b740ffb5f64d',
#  'census_2489': 'e41e2828-a3c7-4981-8d4e-8dec26a6cdd6',
#  'census_2552': 'a6500bc5-01da-4bad-8ee2-326c861a0037',
#  'census_2565': 'a6500bc5-01da-4bad-8ee2-326c861a0037',
#  'census_2577': '26be28b0-1528-496b-b54c-9376f4757eb6',
#  'census_2599': '26be28b0-1528-496b-b54c-9376f4757eb6',
#  'census_2607': '26be28b0-1528-496b-b54c-9376f4757eb6',
#  'census_2612': '26be28b0-1528-496b-b54c-9376f4757eb6',
#  'census_2644': '26be28b0-1528-496b-b54c-9376f4757eb6',
#  'census_271': '84bfdc85-05b2-4fd2-8a9d-8b24d03b2236',
#  'census_2719': '84bfdc85-05b2-4fd2-8a9d-8b24d03b2236',
#  'census_276': '84bfdc85-05b2-4fd2-8a9d-8b24d03b2236',
#  'census_2764': '1e7ddd78-7925-4411-80c1-48c14f53f944',
#  'census_2766': '1e7ddd78-7925-4411-80c1-48c14f53f944',
#  'census_279': '15c2985e-b7f8-4a98-b562-95c5921be14b',
#  'census_28': '15c2985e-b7f8-4a98-b562-95c5921be14b',
#  'census_2843': '15c2985e-b7f8-4a98-b562-95c5921be14b',
#  'census_2861': '15c2985e-b7f8-4a98-b562-95c5921be14b',
#  'census_2876': '15c2985e-b7f8-4a98-b562-95c5921be14b',
#  'census_2878': 'a8c6c92e-e27b-47c7-998c-3bf3f074fe93',
#  'census_2888': 'a8c6c92e-e27b-47c7-998c-3bf3f074fe93',
#  'census_2923': 'a8c6c92e-e27b-47c7-998c-3bf3f074fe93',
#  'census_305': 'a8c6c92e-e27b-47c7-998c-3bf3f074fe93',
#  'census_323': 'a8c6c92e-e27b-47c7-998c-3bf3f074fe93',
#  'census_324': '0d2defd1-25bf-4b0b-a96e-9e0953cf0cfa',
#  'census_389': '0d2defd1-25bf-4b0b-a96e-9e0953cf0cfa',
#  'census_42': '0d2defd1-25bf-4b0b-a96e-9e0953cf0cfa',
#  'census_459': '1d96a5e9-06e9-44f4-bde3-973626037f20',
#  'census_494': '9c5af0a2-732e-44a9-9d19-21fee298036a',
#  'census_508': '0537369e-02be-4048-b4c1-f17bb29abe8e',
#  'census_516': '0537369e-02be-4048-b4c1-f17bb29abe8e',
#  'census_604': '0537369e-02be-4048-b4c1-f17bb29abe8e',
#  'census_609': 'c28e49f8-fc48-4857-b695-abe6aab40c13',
#  'census_617': 'c28e49f8-fc48-4857-b695-abe6aab40c13',
#  'census_624': 'c28e49f8-fc48-4857-b695-abe6aab40c13',
#  'census_641': '3985c953-c687-4423-b5d3-f58336a2cabd',
#  'census_683': '3985c953-c687-4423-b5d3-f58336a2cabd',
#  'census_690': '4e61806d-9f0b-4e62-a04f-bc40fd26bccb',
#  'census_700': '4e61806d-9f0b-4e62-a04f-bc40fd26bccb',
#  'census_718': '4e61806d-9f0b-4e62-a04f-bc40fd26bccb',
#  'census_719': '4e61806d-9f0b-4e62-a04f-bc40fd26bccb',
#  'census_720': 'a060e071-e4c3-45ee-b433-07270c296b69',
#  'census_737': 'a060e071-e4c3-45ee-b433-07270c296b69',
#  'census_744': 'a060e071-e4c3-45ee-b433-07270c296b69',
#  'census_773': 'a03e255b-b1cb-4da8-b636-355e894d7186',
#  'census_78': 'a03e255b-b1cb-4da8-b636-355e894d7186',
#  'census_788': '7dfd1c01-2147-4e95-879b-e19f3bfad5a9',
#  'census_805': '7dfd1c01-2147-4e95-879b-e19f3bfad5a9',
#  'census_874': '7dfd1c01-2147-4e95-879b-e19f3bfad5a9',
#  'census_889': '7dfd1c01-2147-4e95-879b-e19f3bfad5a9',
#  'census_890': '7dfd1c01-2147-4e95-879b-e19f3bfad5a9',
#  'census_9': '36052943-9305-4d5d-95cc-de7c966eca32',
#  'census_903': '36052943-9305-4d5d-95cc-de7c966eca32',
#  'census_910': '36052943-9305-4d5d-95cc-de7c966eca32',
#  'census_924': '36052943-9305-4d5d-95cc-de7c966eca32',
#  'census_1058': '0edb2946-7fd3-43aa-a067-b0a82886f187',
#  'census_108': 'b850cd6c-529d-4a4c-959f-640b5d2182bf',
#  'census_1092': 'b850cd6c-529d-4a4c-959f-640b5d2182bf',
#  'census_1122': 'b850cd6c-529d-4a4c-959f-640b5d2182bf',
#  'census_1142': 'b850cd6c-529d-4a4c-959f-640b5d2182bf',
#  'census_1178': '78187012-1f8a-4343-b684-48ae7a54d60f',
#  'census_1182': '110e5ff8-f36f-4f5d-b8de-4f93b504501c',
#  'census_1226': '110e5ff8-f36f-4f5d-b8de-4f93b504501c',
#  'census_1241': '110e5ff8-f36f-4f5d-b8de-4f93b504501c',
#  'census_1320': '110e5ff8-f36f-4f5d-b8de-4f93b504501c',
#  'census_1334': '690c4b5f-c4e6-4e3e-8b7b-3030e24819d9',
#  'census_1344': '690c4b5f-c4e6-4e3e-8b7b-3030e24819d9',
#  'census_1390': 'f8f95c72-c227-43b4-9bdb-e91dc5a7e32b',
#  'census_1434': '807b849c-b70a-43b8-98ba-b7897054e983',
#  'census_1448': '807b849c-b70a-43b8-98ba-b7897054e983',
#  'census_1456': '807b849c-b70a-43b8-98ba-b7897054e983',
#  'census_16': '65694746-17d4-4392-8827-7c94bfc1d5de',
#  'census_1622': '7246fdef-3fbe-4806-a5bd-c3bcdb248873',
#  'census_1663': '7246fdef-3fbe-4806-a5bd-c3bcdb248873',
#  'census_1668': '7246fdef-3fbe-4806-a5bd-c3bcdb248873',
#  'census_1693': '7246fdef-3fbe-4806-a5bd-c3bcdb248873',
#  'census_1712': '7246fdef-3fbe-4806-a5bd-c3bcdb248873',
#  'census_1767': 'b5e279b0-5fa9-4e30-b436-b22823d088a9',
#  'census_1780': 'b5e279b0-5fa9-4e30-b436-b22823d088a9',
#  'census_1848': '610c0311-53e7-4e9d-989a-08d8b1df34a5',
#  'census_1925': '8edaf7ac-a504-41e5-9a3f-fce1d8c7d028',
#  'census_1933': '8edaf7ac-a504-41e5-9a3f-fce1d8c7d028',
#  'census_1935': '8edaf7ac-a504-41e5-9a3f-fce1d8c7d028',
#  'census_1958': '8edaf7ac-a504-41e5-9a3f-fce1d8c7d028',
#  'census_1988': '8edaf7ac-a504-41e5-9a3f-fce1d8c7d028',
#  'census_2005': '3a09e3df-48e9-4fce-9d82-f5ddd109e337',
#  'census_2051': '7aeb5fb6-97f2-463b-b5db-27f2eb8ed357',
#  'census_373': 'fdab3b23-89fe-4c34-8b57-6be7a40433da',
#  'census_40': 'fdab3b23-89fe-4c34-8b57-6be7a40433da',
#  'census_423': 'fdab3b23-89fe-4c34-8b57-6be7a40433da',
#  'census_432': 'fdab3b23-89fe-4c34-8b57-6be7a40433da',
#  'census_462': 'fdab3b23-89fe-4c34-8b57-6be7a40433da',
#  'census_463': 'aeb43d2c-0688-4645-b14a-06dfbab1025b',
#  'census_470': 'aeb43d2c-0688-4645-b14a-06dfbab1025b',
#  'census_504': 'aeb43d2c-0688-4645-b14a-06dfbab1025b',
#  'census_51': 'aeb43d2c-0688-4645-b14a-06dfbab1025b',
#  'census_519': '15c5fb03-3494-4b5e-a428-dbc50340f3c1',
#  'census_53': '15c5fb03-3494-4b5e-a428-dbc50340f3c1',
#  'census_586': '15c5fb03-3494-4b5e-a428-dbc50340f3c1',
#  'census_588': '15c5fb03-3494-4b5e-a428-dbc50340f3c1',
#  'census_595': '15c5fb03-3494-4b5e-a428-dbc50340f3c1',
#  'census_610': '19f77cd9-5f7c-4943-a6b5-dd9f7eeee221',
#  'census_62': '19f77cd9-5f7c-4943-a6b5-dd9f7eeee221',
#  'census_629': '19f77cd9-5f7c-4943-a6b5-dd9f7eeee221',
#  'census_635': '19f77cd9-5f7c-4943-a6b5-dd9f7eeee221',
#  'census_7': '259ba522-2cd9-4bb1-94a8-bbdb21e47144',
#  'census_741': '259ba522-2cd9-4bb1-94a8-bbdb21e47144',
#  'census_786': '259ba522-2cd9-4bb1-94a8-bbdb21e47144',
#  'census_830': '79d4363c-ba31-4f4a-9257-fabc71641db6',
#  'census_831': '79d4363c-ba31-4f4a-9257-fabc71641db6',
#  'census_86': '79d4363c-ba31-4f4a-9257-fabc71641db6',
#  'census_879': 'eb13dfbb-4094-4fa1-84be-92d9b44d2354',
#  'census_880': 'eb13dfbb-4094-4fa1-84be-92d9b44d2354',
#  'census_900': 'eb13dfbb-4094-4fa1-84be-92d9b44d2354',
#  'census_955': 'eb13dfbb-4094-4fa1-84be-92d9b44d2354',
#  'census_98': '4ec3f45d-9b23-4296-b2b5-fe4b117eac71',
#  'census_980': '4ec3f45d-9b23-4296-b2b5-fe4b117eac71',
#  'census_989': '4ec3f45d-9b23-4296-b2b5-fe4b117eac71',
#  'census_1026': 'f4eea422-88e6-4759-8102-bad6371c74b4',
#  'census_1037': 'f4eea422-88e6-4759-8102-bad6371c74b4',
#  'census_1094': '4dcc86ab-aa50-4715-945e-f722d3672be2',
#  'census_1135': '4dcc86ab-aa50-4715-945e-f722d3672be2',
#  'census_1136': 'f8f8c352-b366-4911-9f3f-6c7401df7f4e',
#  'census_1163': 'f8f8c352-b366-4911-9f3f-6c7401df7f4e',
#  'census_1165': 'f8f8c352-b366-4911-9f3f-6c7401df7f4e',
#  'census_1173': '97b89811-bb45-4f04-9fc3-ef18b7f28a4a',
#  'census_1207': 'fc1efc48-5b32-41ec-afa2-1ef82769e4b2',
#  'census_1251': 'fc1efc48-5b32-41ec-afa2-1ef82769e4b2',
#  'census_1255': 'fc1efc48-5b32-41ec-afa2-1ef82769e4b2',
#  'census_1293': 'd6128a61-cd8e-464d-815b-5ec4bea8d62a',
#  'census_1312': 'd6128a61-cd8e-464d-815b-5ec4bea8d62a',
#  'census_136': '4aecb051-ed0d-4dc1-956c-1a8cbf857f51',
#  'census_1365': '4aecb051-ed0d-4dc1-956c-1a8cbf857f51',
#  'census_1374': '4aecb051-ed0d-4dc1-956c-1a8cbf857f51',
#  'census_1396': '4aecb051-ed0d-4dc1-956c-1a8cbf857f51',
#  'census_1421': '532a32ad-bc68-4ddc-b632-415131c9fa1b',
#  'census_1424': 'b6e420df-8218-403a-af61-e218aa3e65ca',
#  'census_1445': 'a75895e1-a6b0-402a-ac9f-eafb7b16219f',
#  'census_1484': 'a75895e1-a6b0-402a-ac9f-eafb7b16219f',
#  'census_1503': 'a75895e1-a6b0-402a-ac9f-eafb7b16219f',
#  'census_1512': '8942653a-df67-49e6-ba84-de7d5d56c612',
#  'census_1513': '8942653a-df67-49e6-ba84-de7d5d56c612',
#  'census_1524': '8942653a-df67-49e6-ba84-de7d5d56c612',
#  'census_153': '8942653a-df67-49e6-ba84-de7d5d56c612',
#  'census_1606': '8942653a-df67-49e6-ba84-de7d5d56c612',
#  'census_1611': '2389df1b-dc10-45f8-86f3-023c2bddda0f',
#  'census_1673': '2389df1b-dc10-45f8-86f3-023c2bddda0f',
#  'census_1750': 'a9b03a33-aad6-427a-8d31-5fbbf79a8ff9',
#  'census_1771': '839168b0-b248-4f81-b165-f66dece53cde',
#  'census_1939': '31547d35-f9eb-48f0-99e4-7799fb3d9896',
#  'census_1954': '31547d35-f9eb-48f0-99e4-7799fb3d9896',
#  'census_197': '31547d35-f9eb-48f0-99e4-7799fb3d9896',
#  'census_1982': '56cc5212-879c-4bf2-a4a1-fdf2ae8fc507',
#  'census_1995': '56cc5212-879c-4bf2-a4a1-fdf2ae8fc507',
#  'census_2015': '56cc5212-879c-4bf2-a4a1-fdf2ae8fc507',
#  'census_2024': '56cc5212-879c-4bf2-a4a1-fdf2ae8fc507',
#  'census_2043': '56cc5212-879c-4bf2-a4a1-fdf2ae8fc507',
#  'census_2052': '8371aca9-1e6a-4e99-bed3-37a50b7aa03b',
#  'census_2065': '8371aca9-1e6a-4e99-bed3-37a50b7aa03b',
#  'census_2068': '8371aca9-1e6a-4e99-bed3-37a50b7aa03b',
#  'census_2092': '8371aca9-1e6a-4e99-bed3-37a50b7aa03b',
#  'census_2156': '7a9e6f4c-c7e6-480d-95fd-0cb93cdb5873',
#  'census_2164': '7a9e6f4c-c7e6-480d-95fd-0cb93cdb5873',
#  'census_2176': '7a9e6f4c-c7e6-480d-95fd-0cb93cdb5873',
#  'census_2190': '7a9e6f4c-c7e6-480d-95fd-0cb93cdb5873',
#  'census_2208': '23745e48-ce30-422d-83b4-6c279acaedd6',
#  'census_2209': '45ce7a22-bc3c-4d20-a3e1-7a5a13202be3',
#  'census_670': '83160b14-b340-4464-9d17-dd8f5926a14a',
#  'census_677': 'a0bd2c34-265d-48f6-923a-b5acb537abc3',
#  'census_697': 'a0bd2c34-265d-48f6-923a-b5acb537abc3',
#  'census_707': 'a0bd2c34-265d-48f6-923a-b5acb537abc3',
#  'census_71': 'a0bd2c34-265d-48f6-923a-b5acb537abc3',
#  'census_825': 'a0bd2c34-265d-48f6-923a-b5acb537abc3',
#  'census_838': 'b22b31af-c541-456a-87f8-fcd3f450722f',
#  'census_913': 'b22b31af-c541-456a-87f8-fcd3f450722f',
#  'census_937': 'b22b31af-c541-456a-87f8-fcd3f450722f',
#  'census_1': '70b5b031-8e11-46d6-ba9d-45c5e18ddec8',
#  'census_1003': '70b5b031-8e11-46d6-ba9d-45c5e18ddec8',
#  'census_1006': '70b5b031-8e11-46d6-ba9d-45c5e18ddec8',
#  'census_1062': '70b5b031-8e11-46d6-ba9d-45c5e18ddec8',
#  'census_1066': '70b5b031-8e11-46d6-ba9d-45c5e18ddec8',
#  'census_114': '18a25159-451d-492d-a59b-e6ec28c0b06a',
#  'census_1196': '18a25159-451d-492d-a59b-e6ec28c0b06a',
#  'census_1249': '18a25159-451d-492d-a59b-e6ec28c0b06a',
#  'census_1290': '18a25159-451d-492d-a59b-e6ec28c0b06a',
#  'census_1314': 'c7d5529c-8218-44d3-b167-fc018d45399b',
#  'census_1354': '55d83e6f-158d-4f4c-aae5-a5207a260942',
#  'census_1370': '55d83e6f-158d-4f4c-aae5-a5207a260942',
#  'census_1383': '55d83e6f-158d-4f4c-aae5-a5207a260942',
#  'census_1552': '55d83e6f-158d-4f4c-aae5-a5207a260942',
#  'census_1579': '55d83e6f-158d-4f4c-aae5-a5207a260942',
#  'census_1635': 'b291d6e8-b100-4865-ac04-17f0963f3de6',
#  'census_1714': 'b291d6e8-b100-4865-ac04-17f0963f3de6',
#  'census_1723': 'b291d6e8-b100-4865-ac04-17f0963f3de6',
#  'census_175': 'b291d6e8-b100-4865-ac04-17f0963f3de6',
#  'census_1757': '45784aa3-4093-4510-af36-087ae93098fd',
#  'census_1766': '45784aa3-4093-4510-af36-087ae93098fd',
#  'census_1788': '45784aa3-4093-4510-af36-087ae93098fd',
#  'census_180': '45784aa3-4093-4510-af36-087ae93098fd',
#  'census_1874': 'e1dee722-bf8a-44e1-804f-944e9c34f6e3',
#  'census_1914': 'e1dee722-bf8a-44e1-804f-944e9c34f6e3',
#  'census_1998': 'e1dee722-bf8a-44e1-804f-944e9c34f6e3',
#  'census_2029': 'e1dee722-bf8a-44e1-804f-944e9c34f6e3',
#  'census_2071': 'e1dee722-bf8a-44e1-804f-944e9c34f6e3',
#  'census_2096': 'c64cafb1-f1a8-4f5f-bf9a-9d43f7f157f0',
#  'census_2115': 'c64cafb1-f1a8-4f5f-bf9a-9d43f7f157f0',
#  'census_2124': 'c64cafb1-f1a8-4f5f-bf9a-9d43f7f157f0',
#  'census_2126': '8c91d165-1688-4ef5-b573-b1ae567a4465',
#  'census_2201': '8c91d165-1688-4ef5-b573-b1ae567a4465',
#  'census_2214': '541190a3-7c44-4e2d-a71d-62bfff8bd38a',
#  'census_222': '541190a3-7c44-4e2d-a71d-62bfff8bd38a',
#  'census_2245': '541190a3-7c44-4e2d-a71d-62bfff8bd38a',
#  'census_2270': '541190a3-7c44-4e2d-a71d-62bfff8bd38a',
#  'census_2279': '2bd4fe12-d880-462a-99d6-a2639c9d0e88',
#  'census_228': '2bd4fe12-d880-462a-99d6-a2639c9d0e88',
#  'census_229': '2bd4fe12-d880-462a-99d6-a2639c9d0e88',
#  'census_2311': '28741899-403f-471e-ac2f-bc6c38b5335f',
#  'census_232': 'c43f69c3-1628-4828-9d0b-4351793d2ebb',
#  'census_2353': 'c43f69c3-1628-4828-9d0b-4351793d2ebb',
#  'census_2391': 'c43f69c3-1628-4828-9d0b-4351793d2ebb',
#  'census_240': 'c43f69c3-1628-4828-9d0b-4351793d2ebb',
#  'census_2457': 'c43f69c3-1628-4828-9d0b-4351793d2ebb',
#  'census_2464': '4ee59fd6-cd16-458e-a76e-520d1750248c',
#  'census_2522': '4ee59fd6-cd16-458e-a76e-520d1750248c',
#  'census_2575': '4ee59fd6-cd16-458e-a76e-520d1750248c',
#  'census_2602': '4ee59fd6-cd16-458e-a76e-520d1750248c',
#  'census_2631': '5a5c1a89-b791-4ddb-8b00-b1da0798e945',
#  'census_2665': '5a5c1a89-b791-4ddb-8b00-b1da0798e945',
#  'census_2668': '5a5c1a89-b791-4ddb-8b00-b1da0798e945',
#  'census_2672': '5a5c1a89-b791-4ddb-8b00-b1da0798e945',
#  'census_2682': 'd89d3f4e-e127-4ff1-a11b-de0024807838',
#  'census_2699': '285c0028-6e36-4fa2-b2cf-0dcc526f7fef',
#  'census_2812': '19ab099e-b8d3-4e48-b890-98723c133355',
#  'census_2850': '19ab099e-b8d3-4e48-b890-98723c133355',
#  'census_2890': '19ab099e-b8d3-4e48-b890-98723c133355',
#  'census_2895': '19ab099e-b8d3-4e48-b890-98723c133355',
#  'census_2922': 'ebdba3aa-c873-45c0-a00a-39908c4d1174',
#  'census_343': '12022f4b-57d5-4add-9eaa-119b3f67d2a2',
#  'census_41': 'd1d49f23-45bd-405d-9b31-d09a37ea77ab',
#  'census_424': 'd1d49f23-45bd-405d-9b31-d09a37ea77ab',
#  'census_480': 'd1d49f23-45bd-405d-9b31-d09a37ea77ab',
#  'census_482': 'd1d49f23-45bd-405d-9b31-d09a37ea77ab',
#  'census_497': 'd1d49f23-45bd-405d-9b31-d09a37ea77ab',
#  'census_510': 'e08005e8-4e5a-4f7a-b136-42024f8976d9',
#  'census_515': 'e08005e8-4e5a-4f7a-b136-42024f8976d9',
#  'census_520': 'a2fa425e-54a2-4241-a9b9-6d73c4a31e34',
#  'census_529': 'a2fa425e-54a2-4241-a9b9-6d73c4a31e34',
#  'census_575': 'a2fa425e-54a2-4241-a9b9-6d73c4a31e34',
#  'census_577': 'b7b1fee8-e633-4f8e-a5b0-4a625492fc0b',
#  'census_591': '32ca4db7-18bd-4d33-8c6b-7a83fdfaba59',
#  'census_614': '32ca4db7-18bd-4d33-8c6b-7a83fdfaba59',
#  'census_626': 'bd07c289-4b85-4d8b-b931-18077bd6f2f0',
#  'census_730': 'bd07c289-4b85-4d8b-b931-18077bd6f2f0',
#  'census_740': '234dbd2b-2748-40cf-b992-b92375530c05',
#  'census_763': '234dbd2b-2748-40cf-b992-b92375530c05',
#  'census_80': '234dbd2b-2748-40cf-b992-b92375530c05',
#  'census_833': '234dbd2b-2748-40cf-b992-b92375530c05',
#  'census_1012': 'c5e9b7fd-4f74-414b-be98-fc527c485495',
#  'census_1051': 'c5e9b7fd-4f74-414b-be98-fc527c485495',
#  'census_1072': 'c5e9b7fd-4f74-414b-be98-fc527c485495',
#  'census_111': 'c5e9b7fd-4f74-414b-be98-fc527c485495',
#  'census_1120': 'f0f087fd-2870-4d5b-ab00-954935c71146',
#  'census_1151': 'f0f087fd-2870-4d5b-ab00-954935c71146',
#  'census_1152': 'f0f087fd-2870-4d5b-ab00-954935c71146',
#  'census_1155': 'f0f087fd-2870-4d5b-ab00-954935c71146',
#  'census_1174': 'bc6c1749-b5bd-4d6b-a9b5-fc753233bc0b',
#  'census_1177': 'bc6c1749-b5bd-4d6b-a9b5-fc753233bc0b',
#  'census_1191': 'bc6c1749-b5bd-4d6b-a9b5-fc753233bc0b',
#  'census_1193': 'bc6c1749-b5bd-4d6b-a9b5-fc753233bc0b',
#  'census_1218': '48889049-f66e-4b3c-acd3-fb2300054780',
#  'census_1256': 'bba47ec4-7b9a-4d5e-9b72-16533faf0f76',
#  'census_1257': 'bba47ec4-7b9a-4d5e-9b72-16533faf0f76',
#  'census_1262': 'bba47ec4-7b9a-4d5e-9b72-16533faf0f76',
#  'census_1327': 'bba47ec4-7b9a-4d5e-9b72-16533faf0f76',
#  'census_1336': 'bba47ec4-7b9a-4d5e-9b72-16533faf0f76',
#  'census_1433': '58f5a080-b6ae-479d-b5fa-b57ce0972df6',
#  'census_1487': '58f5a080-b6ae-479d-b5fa-b57ce0972df6',
#  'census_150': '58f5a080-b6ae-479d-b5fa-b57ce0972df6',
#  'census_1638': 'cbd2ad1c-efba-436c-899d-9544dbce4a13',
#  'census_1644': 'cbd2ad1c-efba-436c-899d-9544dbce4a13',
#  'census_1648': 'cbd2ad1c-efba-436c-899d-9544dbce4a13',
#  'census_1697': 'cbd2ad1c-efba-436c-899d-9544dbce4a13',
#  'census_1698': 'cbd2ad1c-efba-436c-899d-9544dbce4a13',
#  'census_1722': 'eea20eb3-1553-4f83-8b9d-76f53ec48ad7',
#  'census_1779': 'eea20eb3-1553-4f83-8b9d-76f53ec48ad7',
#  'census_1782': 'eea20eb3-1553-4f83-8b9d-76f53ec48ad7',
#  'census_1799': 'b6cc621b-a6c5-4fa8-b9bc-9ea1894a39f0',
#  'census_1805': 'b6cc621b-a6c5-4fa8-b9bc-9ea1894a39f0',
#  'census_1832': 'b6cc621b-a6c5-4fa8-b9bc-9ea1894a39f0',
#  'census_1842': 'b6cc621b-a6c5-4fa8-b9bc-9ea1894a39f0',
#  ...}

# %%
new_trips['hid'] = new_trips['pid'].map(person_to_household_map)

# %% [markdown]
# ## Input data after changes

# %%
attributes.head()
# Out:
#           gender   job    occ     inc  age
# pid
# census_0  female  work  white     low   43
# census_1  female  work  white     low   44
# census_2    male  work   blue    high   41
# census_3    male  work   blue     low   36
# census_4    male  work   blue  medium   32

# %%
new_trips.head(10)
# Out:
#    seq         uid       pid                                   hid      hzone  \
# 0    0           0  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 1    1    0_act_to  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 2    2  0_act_from  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 3    3           1  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 4    4    1_act_to  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 5    5  1_act_from  census_0  703da4e3-39ff-442e-aa69-07675d0dbd4f     Harrow
# 6    0           2  census_1  70b5b031-8e11-46d6-ba9d-45c5e18ddec8  Greenwich
# 7    1    2_act_to  census_1  70b5b031-8e11-46d6-ba9d-45c5e18ddec8  Greenwich
# 8    2  2_act_from  census_1  70b5b031-8e11-46d6-ba9d-45c5e18ddec8  Greenwich
# 9    3           3  census_1  70b5b031-8e11-46d6-ba9d-45c5e18ddec8  Greenwich
#
#            ozone          dzone      purp  mode   tst   tet  freq
# 0         Harrow         Camden      work    pt   444   473  1000
# 1         Camden       Lewisham   leisure    pt   588   635  1000
# 2       Lewisham         Harrow   leisure    pt   703   768  1000
# 3         Camden         Harrow      work    pt   890   919  1000
# 4         Harrow      Redbridge  shopping  walk  1068  1118  1000
# 5      Redbridge         Camden  shopping  walk  1225  1382  1000
# 6      Greenwich  Tower Hamlets      work    pt   507   528  1000
# 7  Tower Hamlets         Camden    escort   car   556   568  1000
# 8         Camden      Greenwich    escort   car   699   910  1000
# 9  Tower Hamlets      Greenwich      work    pt  1065  1086  1000

# %%
new_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17556 entries, 0 to 17555
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   seq     17556 non-null  int64
#  1   uid     17556 non-null  object
#  2   pid     17556 non-null  object
#  3   hid     17238 non-null  object
#  4   hzone   17556 non-null  object
#  5   ozone   17556 non-null  object
#  6   dzone   17556 non-null  object
#  7   purp    17556 non-null  object
#  8   mode    17556 non-null  object
#  9   tst     17556 non-null  object
#  10  tet     17556 non-null  object
#  11  freq    17556 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.6+ MB

# %%
new_trips['purp'].unique(), new_trips['mode'].unique()
# Out:
# (array(['work', 'leisure', 'shopping', 'escort', 'health', 'education'],
#        dtype=object),
#  array(['pt', 'walk', 'car', 'bike'], dtype=object))

# %%
def print_simple_stats(population):
    """
    Print some simple population statistics.
    """
    time_at_home = 0
    travel_time = 0 
    low_income_central_trips = 0
    high_income_central_trips = 0
    
    for hid, hh in population.households.items():
        for pid, person in hh.people.items():
            freq = person.freq
            
            for p in person.plan:
                if p.act == 'travel':
                    duration = p.duration.seconds * freq / 3600
                    travel_time += duration
                    
                    if p.end_location.area == "Westminster,City of London":
                        if person.attributes['inc'] == "low":
                            low_income_central_trips += freq
                            
                        elif person.attributes['inc'] == "high":
                            high_income_central_trips += freq
                    
                else:  # activity
                    if p.act == 'home':
                        duration = p.duration.seconds * freq / 3600
                        time_at_home += duration
                        
    print(f"Population total time at home: {time_at_home/1000000:.2f} million hours")
    print(f"Population total travel time: {travel_time/1000000:.2f} million hours")
    print(f"Low income trips to Central London: {low_income_central_trips} trips")
    print(f"High income trips to Central London: {high_income_central_trips} trips")

# %% [markdown]
# ## Create the population

# %%
population = parse.load_travel_diary(new_trips, attributes)

# %%
rando_hh_id = list(households_map.keys())[0]
rando_pid_in_hh = list(population.households[rando_hh_id].people)[0]

# %%
population.households[rando_hh_id].people
# Out:
# {'census_1016': <pam.core.Person at 0x119028fd0>,
#  'census_1043': <pam.core.Person at 0x119028750>,
#  'census_1197': <pam.core.Person at 0x11902d850>,
#  'census_1247': <pam.core.Person at 0x1190359d0>}

# %%
population.households[rando_hh_id].people[rando_pid_in_hh].plan.print()
# Out:
# 0:	Activity(0 act:home, location:Barking and Dagenham, time:00:00:00 --> 07:21:00, duration:7:21:00)
# 1:	Leg(0 mode:car, area:Barking and Dagenham --> Barking and Dagenham, time:07:21:00 --> 07:30:00, duration:0:09:00)
# 2:	Activity(1 act:home, location:Barking and Dagenham, time:07:30:00 --> 09:52:00, duration:2:22:00)
# 3:	Leg(1 mode:walk, area:Barking and Dagenham --> Wandsworth, time:09:52:00 --> 14:42:00, duration:4:50:00)
# 4:	Activity(2 act:health, location:Wandsworth, time:14:42:00 --> 15:28:00, duration:0:46:00)
# 5:	Leg(2 mode:walk, area:Wandsworth --> Barking and Dagenham, time:15:28:00 --> 15:59:00, duration:0:31:00)
# 6:	Activity(3 act:home, location:Barking and Dagenham, time:15:59:00 --> 16:02:00, duration:0:03:00)
# 7:	Leg(3 mode:car, area:Barking and Dagenham --> Barking and Dagenham, time:16:02:00 --> 16:11:00, duration:0:09:00)
# 8:	Activity(4 act:home, location:Barking and Dagenham, time:16:11:00 --> 18:13:00, duration:2:02:00)
# 9:	Leg(4 mode:car, area:Barking and Dagenham --> Brent, time:18:13:00 --> 20:22:00, duration:2:09:00)
# 10:	Activity(5 act:health, location:Brent, time:20:22:00 --> 21:10:00, duration:0:48:00)
# 11:	Leg(5 mode:car, area:Brent --> Barking and Dagenham, time:21:10:00 --> 22:49:00, duration:1:39:00)
# 12:	Activity(6 act:home, location:Barking and Dagenham, time:22:49:00 --> 23:59:00, duration:1:10:00)

# %%
population.households[rando_hh_id].people[rando_pid_in_hh].attributes
# Out:
# {'gender': 'other', 'job': 'work', 'occ': 'white', 'inc': 'low', 'age': 36}

# %%
print_simple_stats(population)
# Out:
# Population total time at home: 34.57 million hours
# Population total travel time: 18.90 million hours
# Low income trips to Central London: 495000 trips
# High income trips to Central London: 545000 trips

# %% [markdown]
# # PAM Simple Policies
#
# Based on [link](https://docs.google.com/spreadsheets/d/1FQMa7dLe2cv1NEZnbu5cZo3v07tKXINwvOaLQYoEp-M/edit#gid=0)

# %%
from pam import modify

def apply_policies(population, policies: list):

    new_population = deepcopy(population) 
    for hid, household in new_population.households.items():
        for policy in policies:
            policy.apply_to(household)
    return new_population

# %% [markdown]
# ## Household Quarantine
#
# Probabilistically apply quarantine to a household (remove all activities - stay at home)

# %% [markdown]
# ### Household-based
#
# If you have a probability of a household having to be quarantined

# %%
policy_household_quarantine_per_household = modify.HouseholdQuarantined(
    probability=0.01, 
    person_based=False)

# %%
print_simple_stats(apply_policies(population, [policy_household_quarantine_per_household]))
# Out:
# Population total time at home: 34.98 million hours
# Population total travel time: 18.67 million hours
# Low income trips to Central London: 491000 trips
# High income trips to Central London: 536000 trips

# %% [markdown]
# ### Person-based
#
# If you have a probability of any one person living in the household having to be quarantined.
#
# The probability of the household being quarantined is then $1 - (1-P)^n$, where $P$ is the probability any one person being quarantined and $n$ is the number of people in the household; $(1-P)^n$ is the probability of no one having to be quarantined.

# %%
policy_household_quarantine_per_person = modify.HouseholdQuarantined(
    probability=0.01, 
    person_based=True)

# %%
print_simple_stats(apply_policies(population, [policy_household_quarantine_per_person]))
# Out:
# Population total time at home: 35.37 million hours
# Population total travel time: 18.48 million hours
# Low income trips to Central London: 485000 trips
# High income trips to Central London: 544000 trips

# %% [markdown]
# (Should be equivalent to `RemoveActivity` removing all non-home activities with `policy_type='household'`, and `probability_level='person'`)

# %%
policy_remove_any_education = modify.RemoveActivity(
    ['work', 'leisure', 'shopping', 'health', 'education', 'escort'], 
    policy_type='household',
    probability_level='person',
    probability=0.01)

print_simple_stats(apply_policies(population, [policy_household_quarantine_per_person]))
# Out:
# Population total time at home: 35.93 million hours
# Population total travel time: 18.13 million hours
# Low income trips to Central London: 477000 trips
# High income trips to Central London: 523000 trips

# %% [markdown]
# ## Remove Higher Education
#
# Remove all education activity for persons over age of 17

# %%
def age_condition_over_17(attribute_value):
    return attribute_value > 17

policy_remove_higher_education = modify.RemoveActivity(
    ['education'],
    probability=1, 
    policy_type='person',
    probability_level='person',
    attribute_conditions={'age': age_condition_over_17},
    attribute_strict_conditions=True)

# %%
print_simple_stats(apply_policies(population, [policy_remove_higher_education]))
# Out:
# Population total time at home: 36.53 million hours
# Population total travel time: 17.38 million hours
# Low income trips to Central London: 431000 trips
# High income trips to Central London: 463000 trips

# %% [markdown]
# ## Remove Education
#
# Probabilistically remove education activities from a person

# %%
policy_remove_any_education = modify.RemoveActivity(
    ['education', 'escort'], 
    policy_type='household',
    probability_level='person',
    probability=0.95)

# %%
print_simple_stats(apply_policies(population, [policy_remove_any_education]))
# Out:
# Population total time at home: 41.78 million hours
# Population total travel time: 14.65 million hours
# Low income trips to Central London: 417000 trips
# High income trips to Central London: 440000 trips

# %% [markdown]
# ## Remove Leisure Activities
#
# Remove all leisure activities

# %%
policy_remove_leisure = modify.RemoveActivity(
    ['leisure'], 
    policy_type='person',
    probability_level='person',
    probability=1)

# %%
print_simple_stats(apply_policies(population, [policy_remove_leisure]))
# Out:
# Population total time at home: 39.41 million hours
# Population total travel time: 16.21 million hours
# Low income trips to Central London: 477000 trips
# High income trips to Central London: 525000 trips

# %% [markdown]
# ## Remove Health Activities
#
# Probabilistically remove **individual** health activities from a person

# %%
policy_remove_health = modify.RemoveActivity(
    ['health'], 
    policy_type='activity',
    probability_level='activity',
    probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_remove_health]))
# Out:
# Population total time at home: 36.99 million hours
# Population total travel time: 17.58 million hours
# Low income trips to Central London: 489000 trips
# High income trips to Central London: 538000 trips

# %% [markdown]
# ## Unemployment/Furlough
#
# Probabilistically remove all work activities from a person

# %%
policy_unemployment_and_furlough = modify.RemoveActivity(
    ['work'], 
    policy_type='person',
    probability_level='person',
    probability=0.1)

# %%
print_simple_stats(apply_policies(population, [policy_unemployment_and_furlough]))
# Out:
# Population total time at home: 35.16 million hours
# Population total travel time: 18.43 million hours
# Low income trips to Central London: 453000 trips
# High income trips to Central London: 510000 trips

# %% [markdown]
# ## Work from Home
#
# Probabilistically remove all work activities from a person

# %%
policy_work_from_home = modify.RemoveActivity(
    ['work'], 
    policy_type='person',
    probability_level='person',
    probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_work_from_home]))
# Out:
# Population total time at home: 37.23 million hours
# Population total travel time: 16.59 million hours
# Low income trips to Central London: 334000 trips
# High income trips to Central London: 403000 trips

# %% [markdown]
# ## Reduced Work Activity
#
# Probabilistically remove **individual** work activities from a person

# %%
policy_reduced_work_activity = modify.RemoveActivity(
    ['work'], 
    policy_type='activity',
    probability_level='activity',
    probability=0.2)

# %%
print_simple_stats(apply_policies(population, [policy_reduced_work_activity]))
# Out:
# Population total time at home: 35.75 million hours
# Population total travel time: 17.83 million hours
# Low income trips to Central London: 432000 trips
# High income trips to Central London: 472000 trips

# %% [markdown]
# ## Remove Shopping
#
# Probabilistically remove **individual** shopping activities from a person

# %%
policy_remove_shopping = modify.RemoveActivity(
    ['shop'],
    policy_type='activity',
    probability_level='activity',
    probability=0.5)

# %%
print_simple_stats(apply_policies(population, [policy_remove_shopping]))
# Out:
# Population total time at home: 34.57 million hours
# Population total travel time: 18.90 million hours
# Low income trips to Central London: 495000 trips
# High income trips to Central London: 545000 trips

# %% [markdown]
# ## All together now!

# %%
all_together_pop = apply_policies(
    population, 
    [policy_household_quarantine_per_person, 
     policy_remove_higher_education, 
     policy_remove_any_education, 
     policy_remove_leisure, 
     policy_remove_health, 
     policy_unemployment_and_furlough, 
     policy_work_from_home, 
     policy_reduced_work_activity, 
     policy_remove_shopping])

print_simple_stats(all_together_pop)
# Out:
# Population total time at home: 55.34 million hours
# Population total travel time: 6.97 million hours
# Low income trips to Central London: 194000 trips
# High income trips to Central London: 208000 trips
